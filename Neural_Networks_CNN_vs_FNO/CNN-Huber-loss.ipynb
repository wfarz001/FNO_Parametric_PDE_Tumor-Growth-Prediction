# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from skimage.metrics import structural_similarity as ssim
import pandas as pd

# %%
# Paths to the data
initial_samples_folder = '/home/wfarz001/Fall-2024_Project/Tumor_States/Initial/'
final_samples_folder = '/home/wfarz001/Fall-2024_Project/Tumor_States/Final/'

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

class TumorDataset(Dataset):
    def __init__(self, initial_dir, final_dir, transform=None):
        self.initial_dir = initial_dir
        self.final_dir = final_dir
        self.transform = transform
        self.initial_files = sorted(os.listdir(initial_dir))  # List of initial state files
        self.final_files = sorted(os.listdir(final_dir))  # List of final state files
        
    def __len__(self):
        return len(self.initial_files)
    
    def __getitem__(self, idx):
        initial_file = os.path.join(self.initial_dir, self.initial_files[idx])
        final_file = os.path.join(self.final_dir, self.final_files[idx])
        
        initial_sample = np.load(initial_file)  # Assuming .npy format
        final_sample = np.load(final_file)  # Assuming .npy format
        
        # Convert to torch tensors
        initial_sample = torch.tensor(initial_sample, dtype=torch.float32)
        final_sample = torch.tensor(final_sample, dtype=torch.float32)
        
        if self.transform:
            initial_sample = self.transform(initial_sample)
            final_sample = self.transform(final_sample)
        
        return initial_sample, final_sample

# Create dataset and split it into train, validation, and test
dataset = TumorDataset(initial_samples_folder, final_samples_folder)
train_data, test_data = train_test_split(dataset, test_size=0.3, random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42)

train_loader = DataLoader(train_data, batch_size=4, shuffle=True)
val_loader = DataLoader(val_data, batch_size=4, shuffle=False)
test_loader = DataLoader(test_data, batch_size=4, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class TumorGrowthCNN(nn.Module):
    def __init__(self):
        super(TumorGrowthCNN, self).__init__()
        # Expect 1 input channel (after adding channel dimension)
        self.conv1 = nn.Conv3d(1, 16, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm3d(16)
        self.conv2 = nn.Conv3d(16, 32, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm3d(32)
        self.conv3 = nn.Conv3d(32, 64, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm3d(64)
        self.conv4 = nn.Conv3d(64, 1, kernel_size=1)  # Output: 1 channel

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.conv4(x)
        return x

# %%
# Initialize dataset and dataloaders
dataset = TumorDataset(initial_samples_folder, final_samples_folder)
train_loader = DataLoader(train_data, batch_size=4, shuffle=True)
val_loader = DataLoader(val_data, batch_size=4, shuffle=False)
test_loader = DataLoader(test_data, batch_size=4, shuffle=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize the model, optimizer, and loss function
model = TumorGrowthCNN().to(device)  # Ensure to place model on GPU if available
optimizer = optim.Adam(model.parameters(), lr=1e-4)
loss_fn = nn.SmoothL1Loss()  # Huber loss

# Training loop with validation
num_epochs = 500
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for initial_sample, final_sample in train_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)

        optimizer.zero_grad()
        predicted_final_state = model(initial_sample.unsqueeze(1))  # Add channel dimension (1 for grayscale)
        
        # Compute loss and backpropagate
        loss = loss_fn(predicted_final_state, final_sample.unsqueeze(1))
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # Validation phase after each epoch
    model.eval()  # Set the model to evaluation mode
    val_loss = 0
    with torch.no_grad():
        for initial_sample, final_sample in val_loader:
            initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
            predicted_final_state = model(initial_sample.unsqueeze(1))
            loss = loss_fn(predicted_final_state, final_sample.unsqueeze(1))
            val_loss += loss.item()

    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {total_loss/len(train_loader):.4f}, Validation Loss: {val_loss/len(val_loader):.4f}')
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:605: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv3d(
# Epoch 1/500, Train Loss: 0.0055, Validation Loss: 0.0028
# Epoch 2/500, Train Loss: 0.0014, Validation Loss: 0.0021
# Epoch 3/500, Train Loss: 0.0013, Validation Loss: 0.0018
# Epoch 4/500, Train Loss: 0.0013, Validation Loss: 0.0008
# Epoch 5/500, Train Loss: 0.0010, Validation Loss: 0.0008
# Epoch 6/500, Train Loss: 0.0011, Validation Loss: 0.0008
# Epoch 7/500, Train Loss: 0.0010, Validation Loss: 0.0010
# Epoch 8/500, Train Loss: 0.0012, Validation Loss: 0.0010
# Epoch 9/500, Train Loss: 0.0011, Validation Loss: 0.0011
# Epoch 10/500, Train Loss: 0.0011, Validation Loss: 0.0009
# Epoch 11/500, Train Loss: 0.0010, Validation Loss: 0.0010
# Epoch 12/500, Train Loss: 0.0011, Validation Loss: 0.0007
# Epoch 13/500, Train Loss: 0.0010, Validation Loss: 0.0008
# Epoch 14/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 15/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 16/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 17/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 18/500, Train Loss: 0.0010, Validation Loss: 0.0008
# Epoch 19/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 20/500, Train Loss: 0.0010, Validation Loss: 0.0010
# Epoch 21/500, Train Loss: 0.0011, Validation Loss: 0.0008
# Epoch 22/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 23/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 24/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 25/500, Train Loss: 0.0009, Validation Loss: 0.0011
# Epoch 26/500, Train Loss: 0.0011, Validation Loss: 0.0007
# Epoch 27/500, Train Loss: 0.0010, Validation Loss: 0.0009
# Epoch 28/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 29/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 30/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 31/500, Train Loss: 0.0010, Validation Loss: 0.0008
# Epoch 32/500, Train Loss: 0.0009, Validation Loss: 0.0020
# Epoch 33/500, Train Loss: 0.0011, Validation Loss: 0.0006
# Epoch 34/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 35/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 36/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 37/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 38/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 39/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 40/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 41/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 42/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 43/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 44/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 45/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 46/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 47/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 48/500, Train Loss: 0.0009, Validation Loss: 0.0011
# Epoch 49/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 50/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 51/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 52/500, Train Loss: 0.0009, Validation Loss: 0.0010
# Epoch 53/500, Train Loss: 0.0010, Validation Loss: 0.0006
# Epoch 54/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 55/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 56/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 57/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 58/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 59/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 60/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 61/500, Train Loss: 0.0009, Validation Loss: 0.0010
# Epoch 62/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 63/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 64/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 65/500, Train Loss: 0.0009, Validation Loss: 0.0013
# Epoch 66/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 67/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 68/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 69/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 70/500, Train Loss: 0.0010, Validation Loss: 0.0006
# Epoch 71/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 72/500, Train Loss: 0.0009, Validation Loss: 0.0010
# Epoch 73/500, Train Loss: 0.0010, Validation Loss: 0.0006
# Epoch 74/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 75/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 76/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 77/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 78/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 79/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 80/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 81/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 82/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 83/500, Train Loss: 0.0009, Validation Loss: 0.0010
# Epoch 84/500, Train Loss: 0.0010, Validation Loss: 0.0006
# Epoch 85/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 86/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 87/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 88/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 89/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 90/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 91/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 92/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 93/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 94/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 95/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 96/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 97/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 98/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 99/500, Train Loss: 0.0010, Validation Loss: 0.0015
# Epoch 100/500, Train Loss: 0.0010, Validation Loss: 0.0008
# Epoch 101/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 102/500, Train Loss: 0.0010, Validation Loss: 0.0010
# Epoch 103/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 104/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 105/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 106/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 107/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 108/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 109/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 110/500, Train Loss: 0.0009, Validation Loss: 0.0010
# Epoch 111/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 112/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 113/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 114/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 115/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 116/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 117/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 118/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 119/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 120/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 121/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 122/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 123/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 124/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 125/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 126/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 127/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 128/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 129/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 130/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 131/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 132/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 133/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 134/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 135/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 136/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 137/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 138/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 139/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 140/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 141/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 142/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 143/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 144/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 145/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 146/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 147/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 148/500, Train Loss: 0.0010, Validation Loss: 0.0006
# Epoch 149/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 150/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 151/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 152/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 153/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 154/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 155/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 156/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 157/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 158/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 159/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 160/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 161/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 162/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 163/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 164/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 165/500, Train Loss: 0.0010, Validation Loss: 0.0009
# Epoch 166/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 167/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 168/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 169/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 170/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 171/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 172/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 173/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 174/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 175/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 176/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 177/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 178/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 179/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 180/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 181/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 182/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 183/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 184/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 185/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 186/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 187/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 188/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 189/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 190/500, Train Loss: 0.0009, Validation Loss: 0.0011
# Epoch 191/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 192/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 193/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 194/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 195/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 196/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 197/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 198/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 199/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 200/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 201/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 202/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 203/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 204/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 205/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 206/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 207/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 208/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 209/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 210/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 211/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 212/500, Train Loss: 0.0010, Validation Loss: 0.0007
# Epoch 213/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 214/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 215/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 216/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 217/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 218/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 219/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 220/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 221/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 222/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 223/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 224/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 225/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 226/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 227/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 228/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 229/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 230/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 231/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 232/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 233/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 234/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 235/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 236/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 237/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 238/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 239/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 240/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 241/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 242/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 243/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 244/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 245/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 246/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 247/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 248/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 249/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 250/500, Train Loss: 0.0009, Validation Loss: 0.0011
# Epoch 251/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 252/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 253/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 254/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 255/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 256/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 257/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 258/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 259/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 260/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 261/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 262/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 263/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 264/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 265/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 266/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 267/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 268/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 269/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 270/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 271/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 272/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 273/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 274/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 275/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 276/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 277/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 278/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 279/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 280/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 281/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 282/500, Train Loss: 0.0009, Validation Loss: 0.0010
# Epoch 283/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 284/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 285/500, Train Loss: 0.0009, Validation Loss: 0.0011
# Epoch 286/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 287/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 288/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 289/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 290/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 291/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 292/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 293/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 294/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 295/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 296/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 297/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 298/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 299/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 300/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 301/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 302/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 303/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 304/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 305/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 306/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 307/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 308/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 309/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 310/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 311/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 312/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 313/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 314/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 315/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 316/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 317/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 318/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 319/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 320/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 321/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 322/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 323/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 324/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 325/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 326/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 327/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 328/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 329/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 330/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 331/500, Train Loss: 0.0009, Validation Loss: 0.0009
# Epoch 332/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 333/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 334/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 335/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 336/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 337/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 338/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 339/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 340/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 341/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 342/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 343/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 344/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 345/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 346/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 347/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 348/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 349/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 350/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 351/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 352/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 353/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 354/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 355/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 356/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 357/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 358/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 359/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 360/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 361/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 362/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 363/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 364/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 365/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 366/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 367/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 368/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 369/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 370/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 371/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 372/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 373/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 374/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 375/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 376/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 377/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 378/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 379/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 380/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 381/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 382/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 383/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 384/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 385/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 386/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 387/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 388/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 389/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 390/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 391/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 392/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 393/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 394/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 395/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 396/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 397/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 398/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 399/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 400/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 401/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 402/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 403/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 404/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 405/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 406/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 407/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 408/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 409/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 410/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 411/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 412/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 413/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 414/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 415/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 416/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 417/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 418/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 419/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 420/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 421/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 422/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 423/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 424/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 425/500, Train Loss: 0.0008, Validation Loss: 0.0006
# Epoch 426/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 427/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 428/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 429/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 430/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 431/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 432/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 433/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 434/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 435/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 436/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 437/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 438/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 439/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 440/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 441/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 442/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 443/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 444/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 445/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 446/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 447/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 448/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 449/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 450/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 451/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 452/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 453/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 454/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 455/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 456/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 457/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 458/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 459/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 460/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 461/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 462/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 463/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 464/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 465/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 466/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 467/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 468/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 469/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 470/500, Train Loss: 0.0009, Validation Loss: 0.0008
# Epoch 471/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 472/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 473/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 474/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 475/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 476/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 477/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 478/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 479/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 480/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 481/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 482/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 483/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 484/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 485/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 486/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 487/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 488/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 489/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 490/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 491/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 492/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 493/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 494/500, Train Loss: 0.0009, Validation Loss: 0.0006
# Epoch 495/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 496/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 497/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 498/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 499/500, Train Loss: 0.0009, Validation Loss: 0.0007
# Epoch 500/500, Train Loss: 0.0009, Validation Loss: 0.0006

# %%
# Evaluate the final model on the test data
model.eval()  # Set the model to evaluation mode
test_loss = 0
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        predicted_final_state = model(initial_sample.unsqueeze(1))
        loss = loss_fn(predicted_final_state, final_sample.unsqueeze(1))
        test_loss += loss.item()

print(f'Test Loss: {test_loss/len(test_loader):.4f}')
# Out:
# Test Loss: 0.0007

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Visualize predictions on the test set
def plot_3d_slice(predicted, ground_truth, sample_index=0, slice_index=15):
    predicted_slice = predicted[sample_index, 0, slice_index, :, :].detach().cpu().numpy()  # For predicted tensor with channel dimension
    ground_truth_slice = ground_truth[sample_index, slice_index, :, :].detach().cpu().numpy()  # For ground truth tensor without channel dimension

    # Plotting
    fig, ax = plt.subplots(1, 2, figsize=(12, 6))
    ax[0].imshow(predicted_slice, cmap='hot', interpolation='nearest')
    ax[0].set_title("Predicted")
    ax[0].axis('off')

    ax[1].imshow(ground_truth_slice, cmap='hot', interpolation='nearest')
    ax[1].set_title("Ground Truth")
    ax[1].axis('off')

    plt.show()

# Example usage with a sample index of 0 and a slice index of 15
model.eval()
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        predicted_final_state = model(initial_sample.unsqueeze(1))

        # Visualize the first sample and slice
        plot_3d_slice(predicted_final_state, final_sample, sample_index=0, slice_index=15)
        break  # Just plot one batch for demonstration

# %%
# !pip install pytorch-msssim
# Out:
# Requirement already satisfied: pytorch-msssim in /home/wfarz001/envs/default-pytorch-gpu-2.1.0/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from pytorch-msssim) (2.1.0+cu118)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.12.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (2023.4.0)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->pytorch-msssim) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->pytorch-msssim) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
def rmse(predictions, targets):
    return torch.sqrt(torch.mean((predictions - targets) ** 2))

def mae(predictions, targets):
    return torch.mean(torch.abs(predictions - targets))

from sklearn.metrics import r2_score

def r2_score_pytorch(predictions, targets):
    predictions = predictions.detach().cpu().numpy()  # Convert to numpy
    targets = targets.detach().cpu().numpy()
    return r2_score(targets.flatten(), predictions.flatten())

def psnr(predictions, targets, max_pixel=1.0):
    mse = torch.mean((predictions - targets) ** 2)
    psnr_value = 20 * torch.log10(max_pixel / torch.sqrt(mse))
    return psnr_value

from pytorch_msssim import ssim

def compute_ssim(predictions, targets):
    return ssim(predictions, targets)

def dice_coefficient(predictions, targets, threshold=0.5):
    # Convert to binary masks based on the threshold
    predictions = predictions > threshold
    targets = targets > threshold
    intersection = torch.sum(predictions * targets)
    union = torch.sum(predictions) + torch.sum(targets)
    return (2 * intersection + 1e-6) / (union + 1e-6)

def mape(predictions, targets):
    return torch.mean(torch.abs((predictions - targets) / targets)) * 100

# %%
from sklearn.metrics import r2_score

# Initialize the metrics
rmse_vals = []
mae_vals = []
r2_vals = []
psnr_vals = []
ssim_vals = []
dsc_vals = []
mape_vals = []

model.eval()  # Set the model to evaluation mode
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        
        predicted_final_state = model(initial_sample.unsqueeze(1))  # Add channel dimension (1 for grayscale)

        # Calculate each metric
        rmse_vals.append(rmse(predicted_final_state, final_sample.unsqueeze(1)).item())
        mae_vals.append(mae(predicted_final_state, final_sample.unsqueeze(1)).item())
        r2_vals.append(r2_score_pytorch(predicted_final_state, final_sample.unsqueeze(1)))
        psnr_vals.append(psnr(predicted_final_state, final_sample.unsqueeze(1)).item())
        ssim_vals.append(compute_ssim(predicted_final_state, final_sample.unsqueeze(1)).item())
        dsc_vals.append(dice_coefficient(predicted_final_state, final_sample.unsqueeze(1)).item())
        mape_vals.append(mape(predicted_final_state, final_sample.unsqueeze(1)).item())

# Average the results over the test set
print(f"Average RMSE: {torch.mean(torch.tensor(rmse_vals))}")
print(f"Average MAE: {torch.mean(torch.tensor(mae_vals))}")
print(f"Average R² Score: {torch.mean(torch.tensor(r2_vals))}")
print(f"Average PSNR: {torch.mean(torch.tensor(psnr_vals))}")
print(f"Average SSIM: {torch.mean(torch.tensor(ssim_vals))}")
print(f"Average Dice Similarity Coefficient: {torch.mean(torch.tensor(dsc_vals))}")
print(f"Average MAPE: {torch.mean(torch.tensor(mape_vals))}%")
# Out:
# Average RMSE: 0.036381132900714874
# Average MAE: 0.0076176682487130165
# Average R² Score: 0.7861357306415776
# Average PSNR: 28.999034881591797
# Average SSIM: 0.999535858631134
# Average Dice Similarity Coefficient: 0.6168705224990845
# Average MAPE: 2.0231358476449894e+23%
