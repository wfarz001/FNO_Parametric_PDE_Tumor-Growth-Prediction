# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from skimage.metrics import structural_similarity as ssim
import pandas as pd

# %%
# Paths to the data
initial_samples_folder = '/home/wfarz001/Fall-2024_Project/Tumor_States/Initial/'
final_samples_folder = '/home/wfarz001/Fall-2024_Project/Tumor_States/Final/'

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

class TumorDataset(Dataset):
    def __init__(self, initial_dir, final_dir, transform=None):
        self.initial_dir = initial_dir
        self.final_dir = final_dir
        self.transform = transform
        self.initial_files = sorted(os.listdir(initial_dir))  # List of initial state files
        self.final_files = sorted(os.listdir(final_dir))  # List of final state files
        
    def __len__(self):
        return len(self.initial_files)
    
    def __getitem__(self, idx):
        initial_file = os.path.join(self.initial_dir, self.initial_files[idx])
        final_file = os.path.join(self.final_dir, self.final_files[idx])
        
        initial_sample = np.load(initial_file)  # Assuming .npy format
        final_sample = np.load(final_file)  # Assuming .npy format
        
        # Convert to torch tensors
        initial_sample = torch.tensor(initial_sample, dtype=torch.float32)
        final_sample = torch.tensor(final_sample, dtype=torch.float32)
        
        if self.transform:
            initial_sample = self.transform(initial_sample)
            final_sample = self.transform(final_sample)
        
        return initial_sample, final_sample

# Create dataset and split it into train, validation, and test
dataset = TumorDataset(initial_samples_folder, final_samples_folder)
train_data, test_data = train_test_split(dataset, test_size=0.3, random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42)

train_loader = DataLoader(train_data, batch_size=4, shuffle=True)
val_loader = DataLoader(val_data, batch_size=4, shuffle=False)
test_loader = DataLoader(test_data, batch_size=4, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class TumorGrowthCNN(nn.Module):
    def __init__(self):
        super(TumorGrowthCNN, self).__init__()
        # Expect 1 input channel (after adding channel dimension)
        self.conv1 = nn.Conv3d(1, 16, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm3d(16)
        self.conv2 = nn.Conv3d(16, 32, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm3d(32)
        self.conv3 = nn.Conv3d(32, 64, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm3d(64)
        self.conv4 = nn.Conv3d(64, 1, kernel_size=1)  # Output: 1 channel

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.conv4(x)
        return x

# %%
# Initialize dataset and dataloaders
dataset = TumorDataset(initial_samples_folder, final_samples_folder)
train_loader = DataLoader(train_data, batch_size=4, shuffle=True)
val_loader = DataLoader(val_data, batch_size=4, shuffle=False)
test_loader = DataLoader(test_data, batch_size=4, shuffle=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize the model, optimizer, and loss function
model = TumorGrowthCNN().to(device)  # Ensure to place model on GPU if available
optimizer = optim.Adam(model.parameters(), lr=1e-4)
loss_fn = nn.L1Loss()  # MAE loss

# Training loop with validation
num_epochs = 500
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for initial_sample, final_sample in train_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)

        optimizer.zero_grad()
        predicted_final_state = model(initial_sample.unsqueeze(1))  # Add channel dimension (1 for grayscale)
        
        # Compute loss and backpropagate
        loss = loss_fn(predicted_final_state, final_sample.unsqueeze(1))
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # Validation phase after each epoch
    model.eval()  # Set the model to evaluation mode
    val_loss = 0
    with torch.no_grad():
        for initial_sample, final_sample in val_loader:
            initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
            predicted_final_state = model(initial_sample.unsqueeze(1))
            loss = loss_fn(predicted_final_state, final_sample.unsqueeze(1))
            val_loss += loss.item()

    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {total_loss/len(train_loader):.4f}, Validation Loss: {val_loss/len(val_loader):.4f}')
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:605: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv3d(
# Epoch 1/500, Train Loss: 0.0323, Validation Loss: 0.0242
# Epoch 2/500, Train Loss: 0.0141, Validation Loss: 0.0223
# Epoch 3/500, Train Loss: 0.0127, Validation Loss: 0.0164
# Epoch 4/500, Train Loss: 0.0116, Validation Loss: 0.0117
# Epoch 5/500, Train Loss: 0.0103, Validation Loss: 0.0090
# Epoch 6/500, Train Loss: 0.0100, Validation Loss: 0.0099
# Epoch 7/500, Train Loss: 0.0105, Validation Loss: 0.0103
# Epoch 8/500, Train Loss: 0.0097, Validation Loss: 0.0096
# Epoch 9/500, Train Loss: 0.0097, Validation Loss: 0.0093
# Epoch 10/500, Train Loss: 0.0094, Validation Loss: 0.0103
# Epoch 11/500, Train Loss: 0.0095, Validation Loss: 0.0095
# Epoch 12/500, Train Loss: 0.0094, Validation Loss: 0.0081
# Epoch 13/500, Train Loss: 0.0093, Validation Loss: 0.0086
# Epoch 14/500, Train Loss: 0.0095, Validation Loss: 0.0086
# Epoch 15/500, Train Loss: 0.0114, Validation Loss: 0.0089
# Epoch 16/500, Train Loss: 0.0098, Validation Loss: 0.0080
# Epoch 17/500, Train Loss: 0.0094, Validation Loss: 0.0087
# Epoch 18/500, Train Loss: 0.0091, Validation Loss: 0.0082
# Epoch 19/500, Train Loss: 0.0087, Validation Loss: 0.0087
# Epoch 20/500, Train Loss: 0.0092, Validation Loss: 0.0082
# Epoch 21/500, Train Loss: 0.0091, Validation Loss: 0.0102
# Epoch 22/500, Train Loss: 0.0090, Validation Loss: 0.0095
# Epoch 23/500, Train Loss: 0.0092, Validation Loss: 0.0085
# Epoch 24/500, Train Loss: 0.0090, Validation Loss: 0.0087
# Epoch 25/500, Train Loss: 0.0093, Validation Loss: 0.0078
# Epoch 26/500, Train Loss: 0.0090, Validation Loss: 0.0092
# Epoch 27/500, Train Loss: 0.0088, Validation Loss: 0.0078
# Epoch 28/500, Train Loss: 0.0091, Validation Loss: 0.0093
# Epoch 29/500, Train Loss: 0.0090, Validation Loss: 0.0087
# Epoch 30/500, Train Loss: 0.0088, Validation Loss: 0.0082
# Epoch 31/500, Train Loss: 0.0089, Validation Loss: 0.0076
# Epoch 32/500, Train Loss: 0.0088, Validation Loss: 0.0079
# Epoch 33/500, Train Loss: 0.0088, Validation Loss: 0.0080
# Epoch 34/500, Train Loss: 0.0083, Validation Loss: 0.0079
# Epoch 35/500, Train Loss: 0.0089, Validation Loss: 0.0081
# Epoch 36/500, Train Loss: 0.0089, Validation Loss: 0.0080
# Epoch 37/500, Train Loss: 0.0089, Validation Loss: 0.0081
# Epoch 38/500, Train Loss: 0.0087, Validation Loss: 0.0083
# Epoch 39/500, Train Loss: 0.0093, Validation Loss: 0.0081
# Epoch 40/500, Train Loss: 0.0087, Validation Loss: 0.0079
# Epoch 41/500, Train Loss: 0.0088, Validation Loss: 0.0077
# Epoch 42/500, Train Loss: 0.0087, Validation Loss: 0.0078
# Epoch 43/500, Train Loss: 0.0086, Validation Loss: 0.0092
# Epoch 44/500, Train Loss: 0.0088, Validation Loss: 0.0097
# Epoch 45/500, Train Loss: 0.0088, Validation Loss: 0.0087
# Epoch 46/500, Train Loss: 0.0087, Validation Loss: 0.0082
# Epoch 47/500, Train Loss: 0.0093, Validation Loss: 0.0075
# Epoch 48/500, Train Loss: 0.0084, Validation Loss: 0.0087
# Epoch 49/500, Train Loss: 0.0087, Validation Loss: 0.0080
# Epoch 50/500, Train Loss: 0.0085, Validation Loss: 0.0081
# Epoch 51/500, Train Loss: 0.0084, Validation Loss: 0.0079
# Epoch 52/500, Train Loss: 0.0085, Validation Loss: 0.0078
# Epoch 53/500, Train Loss: 0.0085, Validation Loss: 0.0088
# Epoch 54/500, Train Loss: 0.0089, Validation Loss: 0.0082
# Epoch 55/500, Train Loss: 0.0084, Validation Loss: 0.0078
# Epoch 56/500, Train Loss: 0.0088, Validation Loss: 0.0081
# Epoch 57/500, Train Loss: 0.0090, Validation Loss: 0.0092
# Epoch 58/500, Train Loss: 0.0085, Validation Loss: 0.0081
# Epoch 59/500, Train Loss: 0.0086, Validation Loss: 0.0077
# Epoch 60/500, Train Loss: 0.0086, Validation Loss: 0.0089
# Epoch 61/500, Train Loss: 0.0085, Validation Loss: 0.0077
# Epoch 62/500, Train Loss: 0.0085, Validation Loss: 0.0084
# Epoch 63/500, Train Loss: 0.0089, Validation Loss: 0.0082
# Epoch 64/500, Train Loss: 0.0085, Validation Loss: 0.0076
# Epoch 65/500, Train Loss: 0.0085, Validation Loss: 0.0087
# Epoch 66/500, Train Loss: 0.0085, Validation Loss: 0.0079
# Epoch 67/500, Train Loss: 0.0083, Validation Loss: 0.0075
# Epoch 68/500, Train Loss: 0.0085, Validation Loss: 0.0081
# Epoch 69/500, Train Loss: 0.0084, Validation Loss: 0.0079
# Epoch 70/500, Train Loss: 0.0084, Validation Loss: 0.0080
# Epoch 71/500, Train Loss: 0.0086, Validation Loss: 0.0077
# Epoch 72/500, Train Loss: 0.0084, Validation Loss: 0.0077
# Epoch 73/500, Train Loss: 0.0084, Validation Loss: 0.0086
# Epoch 74/500, Train Loss: 0.0087, Validation Loss: 0.0077
# Epoch 75/500, Train Loss: 0.0084, Validation Loss: 0.0076
# Epoch 76/500, Train Loss: 0.0086, Validation Loss: 0.0086
# Epoch 77/500, Train Loss: 0.0084, Validation Loss: 0.0078
# Epoch 78/500, Train Loss: 0.0083, Validation Loss: 0.0081
# Epoch 79/500, Train Loss: 0.0084, Validation Loss: 0.0078
# Epoch 80/500, Train Loss: 0.0085, Validation Loss: 0.0086
# Epoch 81/500, Train Loss: 0.0084, Validation Loss: 0.0076
# Epoch 82/500, Train Loss: 0.0084, Validation Loss: 0.0076
# Epoch 83/500, Train Loss: 0.0084, Validation Loss: 0.0084
# Epoch 84/500, Train Loss: 0.0084, Validation Loss: 0.0081
# Epoch 85/500, Train Loss: 0.0084, Validation Loss: 0.0083
# Epoch 86/500, Train Loss: 0.0084, Validation Loss: 0.0077
# Epoch 87/500, Train Loss: 0.0084, Validation Loss: 0.0088
# Epoch 88/500, Train Loss: 0.0083, Validation Loss: 0.0098
# Epoch 89/500, Train Loss: 0.0085, Validation Loss: 0.0074
# Epoch 90/500, Train Loss: 0.0087, Validation Loss: 0.0096
# Epoch 91/500, Train Loss: 0.0086, Validation Loss: 0.0084
# Epoch 92/500, Train Loss: 0.0086, Validation Loss: 0.0074
# Epoch 93/500, Train Loss: 0.0084, Validation Loss: 0.0083
# Epoch 94/500, Train Loss: 0.0083, Validation Loss: 0.0077
# Epoch 95/500, Train Loss: 0.0084, Validation Loss: 0.0073
# Epoch 96/500, Train Loss: 0.0085, Validation Loss: 0.0083
# Epoch 97/500, Train Loss: 0.0083, Validation Loss: 0.0080
# Epoch 98/500, Train Loss: 0.0083, Validation Loss: 0.0080
# Epoch 99/500, Train Loss: 0.0083, Validation Loss: 0.0075
# Epoch 100/500, Train Loss: 0.0088, Validation Loss: 0.0087
# Epoch 101/500, Train Loss: 0.0085, Validation Loss: 0.0084
# Epoch 102/500, Train Loss: 0.0084, Validation Loss: 0.0083
# Epoch 103/500, Train Loss: 0.0083, Validation Loss: 0.0079
# Epoch 104/500, Train Loss: 0.0083, Validation Loss: 0.0079
# Epoch 105/500, Train Loss: 0.0083, Validation Loss: 0.0082
# Epoch 106/500, Train Loss: 0.0083, Validation Loss: 0.0076
# Epoch 107/500, Train Loss: 0.0084, Validation Loss: 0.0079
# Epoch 108/500, Train Loss: 0.0083, Validation Loss: 0.0076
# Epoch 109/500, Train Loss: 0.0084, Validation Loss: 0.0077
# Epoch 110/500, Train Loss: 0.0084, Validation Loss: 0.0075
# Epoch 111/500, Train Loss: 0.0084, Validation Loss: 0.0075
# Epoch 112/500, Train Loss: 0.0083, Validation Loss: 0.0078
# Epoch 113/500, Train Loss: 0.0083, Validation Loss: 0.0078
# Epoch 114/500, Train Loss: 0.0083, Validation Loss: 0.0083
# Epoch 115/500, Train Loss: 0.0082, Validation Loss: 0.0078
# Epoch 116/500, Train Loss: 0.0083, Validation Loss: 0.0072
# Epoch 117/500, Train Loss: 0.0085, Validation Loss: 0.0072
# Epoch 118/500, Train Loss: 0.0084, Validation Loss: 0.0077
# Epoch 119/500, Train Loss: 0.0083, Validation Loss: 0.0076
# Epoch 120/500, Train Loss: 0.0083, Validation Loss: 0.0075
# Epoch 121/500, Train Loss: 0.0082, Validation Loss: 0.0075
# Epoch 122/500, Train Loss: 0.0084, Validation Loss: 0.0076
# Epoch 123/500, Train Loss: 0.0081, Validation Loss: 0.0089
# Epoch 124/500, Train Loss: 0.0083, Validation Loss: 0.0079
# Epoch 125/500, Train Loss: 0.0082, Validation Loss: 0.0077
# Epoch 126/500, Train Loss: 0.0083, Validation Loss: 0.0082
# Epoch 127/500, Train Loss: 0.0083, Validation Loss: 0.0074
# Epoch 128/500, Train Loss: 0.0084, Validation Loss: 0.0082
# Epoch 129/500, Train Loss: 0.0082, Validation Loss: 0.0076
# Epoch 130/500, Train Loss: 0.0082, Validation Loss: 0.0077
# Epoch 131/500, Train Loss: 0.0082, Validation Loss: 0.0077
# Epoch 132/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 133/500, Train Loss: 0.0084, Validation Loss: 0.0089
# Epoch 134/500, Train Loss: 0.0085, Validation Loss: 0.0077
# Epoch 135/500, Train Loss: 0.0083, Validation Loss: 0.0075
# Epoch 136/500, Train Loss: 0.0082, Validation Loss: 0.0075
# Epoch 137/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 138/500, Train Loss: 0.0082, Validation Loss: 0.0074
# Epoch 139/500, Train Loss: 0.0083, Validation Loss: 0.0079
# Epoch 140/500, Train Loss: 0.0083, Validation Loss: 0.0075
# Epoch 141/500, Train Loss: 0.0082, Validation Loss: 0.0074
# Epoch 142/500, Train Loss: 0.0082, Validation Loss: 0.0072
# Epoch 143/500, Train Loss: 0.0083, Validation Loss: 0.0084
# Epoch 144/500, Train Loss: 0.0083, Validation Loss: 0.0078
# Epoch 145/500, Train Loss: 0.0082, Validation Loss: 0.0079
# Epoch 146/500, Train Loss: 0.0082, Validation Loss: 0.0072
# Epoch 147/500, Train Loss: 0.0081, Validation Loss: 0.0079
# Epoch 148/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 149/500, Train Loss: 0.0083, Validation Loss: 0.0084
# Epoch 150/500, Train Loss: 0.0083, Validation Loss: 0.0075
# Epoch 151/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 152/500, Train Loss: 0.0082, Validation Loss: 0.0075
# Epoch 153/500, Train Loss: 0.0083, Validation Loss: 0.0079
# Epoch 154/500, Train Loss: 0.0083, Validation Loss: 0.0079
# Epoch 155/500, Train Loss: 0.0083, Validation Loss: 0.0073
# Epoch 156/500, Train Loss: 0.0084, Validation Loss: 0.0073
# Epoch 157/500, Train Loss: 0.0082, Validation Loss: 0.0084
# Epoch 158/500, Train Loss: 0.0083, Validation Loss: 0.0073
# Epoch 159/500, Train Loss: 0.0084, Validation Loss: 0.0084
# Epoch 160/500, Train Loss: 0.0082, Validation Loss: 0.0081
# Epoch 161/500, Train Loss: 0.0083, Validation Loss: 0.0078
# Epoch 162/500, Train Loss: 0.0083, Validation Loss: 0.0073
# Epoch 163/500, Train Loss: 0.0082, Validation Loss: 0.0076
# Epoch 164/500, Train Loss: 0.0082, Validation Loss: 0.0079
# Epoch 165/500, Train Loss: 0.0084, Validation Loss: 0.0080
# Epoch 166/500, Train Loss: 0.0083, Validation Loss: 0.0075
# Epoch 167/500, Train Loss: 0.0082, Validation Loss: 0.0079
# Epoch 168/500, Train Loss: 0.0083, Validation Loss: 0.0077
# Epoch 169/500, Train Loss: 0.0082, Validation Loss: 0.0076
# Epoch 170/500, Train Loss: 0.0082, Validation Loss: 0.0083
# Epoch 171/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 172/500, Train Loss: 0.0083, Validation Loss: 0.0075
# Epoch 173/500, Train Loss: 0.0082, Validation Loss: 0.0074
# Epoch 174/500, Train Loss: 0.0083, Validation Loss: 0.0082
# Epoch 175/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 176/500, Train Loss: 0.0083, Validation Loss: 0.0082
# Epoch 177/500, Train Loss: 0.0083, Validation Loss: 0.0082
# Epoch 178/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 179/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 180/500, Train Loss: 0.0083, Validation Loss: 0.0081
# Epoch 181/500, Train Loss: 0.0083, Validation Loss: 0.0074
# Epoch 182/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 183/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 184/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 185/500, Train Loss: 0.0084, Validation Loss: 0.0076
# Epoch 186/500, Train Loss: 0.0084, Validation Loss: 0.0078
# Epoch 187/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 188/500, Train Loss: 0.0083, Validation Loss: 0.0076
# Epoch 189/500, Train Loss: 0.0083, Validation Loss: 0.0076
# Epoch 190/500, Train Loss: 0.0082, Validation Loss: 0.0079
# Epoch 191/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 192/500, Train Loss: 0.0082, Validation Loss: 0.0080
# Epoch 193/500, Train Loss: 0.0082, Validation Loss: 0.0083
# Epoch 194/500, Train Loss: 0.0085, Validation Loss: 0.0074
# Epoch 195/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 196/500, Train Loss: 0.0082, Validation Loss: 0.0075
# Epoch 197/500, Train Loss: 0.0082, Validation Loss: 0.0089
# Epoch 198/500, Train Loss: 0.0083, Validation Loss: 0.0074
# Epoch 199/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 200/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 201/500, Train Loss: 0.0082, Validation Loss: 0.0076
# Epoch 202/500, Train Loss: 0.0082, Validation Loss: 0.0074
# Epoch 203/500, Train Loss: 0.0083, Validation Loss: 0.0072
# Epoch 204/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 205/500, Train Loss: 0.0081, Validation Loss: 0.0078
# Epoch 206/500, Train Loss: 0.0083, Validation Loss: 0.0074
# Epoch 207/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 208/500, Train Loss: 0.0083, Validation Loss: 0.0077
# Epoch 209/500, Train Loss: 0.0083, Validation Loss: 0.0081
# Epoch 210/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 211/500, Train Loss: 0.0082, Validation Loss: 0.0092
# Epoch 212/500, Train Loss: 0.0082, Validation Loss: 0.0081
# Epoch 213/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 214/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 215/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 216/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 217/500, Train Loss: 0.0081, Validation Loss: 0.0071
# Epoch 218/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 219/500, Train Loss: 0.0082, Validation Loss: 0.0077
# Epoch 220/500, Train Loss: 0.0080, Validation Loss: 0.0074
# Epoch 221/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 222/500, Train Loss: 0.0082, Validation Loss: 0.0074
# Epoch 223/500, Train Loss: 0.0083, Validation Loss: 0.0083
# Epoch 224/500, Train Loss: 0.0083, Validation Loss: 0.0084
# Epoch 225/500, Train Loss: 0.0083, Validation Loss: 0.0089
# Epoch 226/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 227/500, Train Loss: 0.0082, Validation Loss: 0.0078
# Epoch 228/500, Train Loss: 0.0082, Validation Loss: 0.0074
# Epoch 229/500, Train Loss: 0.0082, Validation Loss: 0.0083
# Epoch 230/500, Train Loss: 0.0083, Validation Loss: 0.0072
# Epoch 231/500, Train Loss: 0.0082, Validation Loss: 0.0075
# Epoch 232/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 233/500, Train Loss: 0.0081, Validation Loss: 0.0078
# Epoch 234/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 235/500, Train Loss: 0.0082, Validation Loss: 0.0074
# Epoch 236/500, Train Loss: 0.0081, Validation Loss: 0.0078
# Epoch 237/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 238/500, Train Loss: 0.0082, Validation Loss: 0.0075
# Epoch 239/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 240/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 241/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 242/500, Train Loss: 0.0081, Validation Loss: 0.0078
# Epoch 243/500, Train Loss: 0.0081, Validation Loss: 0.0088
# Epoch 244/500, Train Loss: 0.0082, Validation Loss: 0.0082
# Epoch 245/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 246/500, Train Loss: 0.0082, Validation Loss: 0.0085
# Epoch 247/500, Train Loss: 0.0082, Validation Loss: 0.0081
# Epoch 248/500, Train Loss: 0.0081, Validation Loss: 0.0080
# Epoch 249/500, Train Loss: 0.0082, Validation Loss: 0.0075
# Epoch 250/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 251/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 252/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 253/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 254/500, Train Loss: 0.0081, Validation Loss: 0.0071
# Epoch 255/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 256/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 257/500, Train Loss: 0.0082, Validation Loss: 0.0072
# Epoch 258/500, Train Loss: 0.0081, Validation Loss: 0.0084
# Epoch 259/500, Train Loss: 0.0082, Validation Loss: 0.0075
# Epoch 260/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 261/500, Train Loss: 0.0081, Validation Loss: 0.0079
# Epoch 262/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 263/500, Train Loss: 0.0082, Validation Loss: 0.0083
# Epoch 264/500, Train Loss: 0.0083, Validation Loss: 0.0079
# Epoch 265/500, Train Loss: 0.0082, Validation Loss: 0.0071
# Epoch 266/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 267/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 268/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 269/500, Train Loss: 0.0082, Validation Loss: 0.0075
# Epoch 270/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 271/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 272/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 273/500, Train Loss: 0.0081, Validation Loss: 0.0080
# Epoch 274/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 275/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 276/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 277/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 278/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 279/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 280/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 281/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 282/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 283/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 284/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 285/500, Train Loss: 0.0081, Validation Loss: 0.0080
# Epoch 286/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 287/500, Train Loss: 0.0082, Validation Loss: 0.0082
# Epoch 288/500, Train Loss: 0.0081, Validation Loss: 0.0071
# Epoch 289/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 290/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 291/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 292/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 293/500, Train Loss: 0.0081, Validation Loss: 0.0071
# Epoch 294/500, Train Loss: 0.0082, Validation Loss: 0.0074
# Epoch 295/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 296/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 297/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 298/500, Train Loss: 0.0081, Validation Loss: 0.0079
# Epoch 299/500, Train Loss: 0.0082, Validation Loss: 0.0080
# Epoch 300/500, Train Loss: 0.0083, Validation Loss: 0.0076
# Epoch 301/500, Train Loss: 0.0082, Validation Loss: 0.0071
# Epoch 302/500, Train Loss: 0.0081, Validation Loss: 0.0078
# Epoch 303/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 304/500, Train Loss: 0.0082, Validation Loss: 0.0079
# Epoch 305/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 306/500, Train Loss: 0.0080, Validation Loss: 0.0076
# Epoch 307/500, Train Loss: 0.0082, Validation Loss: 0.0077
# Epoch 308/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 309/500, Train Loss: 0.0082, Validation Loss: 0.0076
# Epoch 310/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 311/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 312/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 313/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 314/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 315/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 316/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 317/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 318/500, Train Loss: 0.0082, Validation Loss: 0.0072
# Epoch 319/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 320/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 321/500, Train Loss: 0.0083, Validation Loss: 0.0071
# Epoch 322/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 323/500, Train Loss: 0.0082, Validation Loss: 0.0081
# Epoch 324/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 325/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 326/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 327/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 328/500, Train Loss: 0.0081, Validation Loss: 0.0070
# Epoch 329/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 330/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 331/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 332/500, Train Loss: 0.0081, Validation Loss: 0.0078
# Epoch 333/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 334/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 335/500, Train Loss: 0.0080, Validation Loss: 0.0071
# Epoch 336/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 337/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 338/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 339/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 340/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 341/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 342/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 343/500, Train Loss: 0.0080, Validation Loss: 0.0074
# Epoch 344/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 345/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 346/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 347/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 348/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 349/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 350/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 351/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 352/500, Train Loss: 0.0080, Validation Loss: 0.0075
# Epoch 353/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 354/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 355/500, Train Loss: 0.0081, Validation Loss: 0.0078
# Epoch 356/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 357/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 358/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 359/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 360/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 361/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 362/500, Train Loss: 0.0083, Validation Loss: 0.0073
# Epoch 363/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 364/500, Train Loss: 0.0083, Validation Loss: 0.0075
# Epoch 365/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 366/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 367/500, Train Loss: 0.0082, Validation Loss: 0.0077
# Epoch 368/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 369/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 370/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 371/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 372/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 373/500, Train Loss: 0.0080, Validation Loss: 0.0074
# Epoch 374/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 375/500, Train Loss: 0.0080, Validation Loss: 0.0074
# Epoch 376/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 377/500, Train Loss: 0.0082, Validation Loss: 0.0076
# Epoch 378/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 379/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 380/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 381/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 382/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 383/500, Train Loss: 0.0080, Validation Loss: 0.0076
# Epoch 384/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 385/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 386/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 387/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 388/500, Train Loss: 0.0081, Validation Loss: 0.0071
# Epoch 389/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 390/500, Train Loss: 0.0081, Validation Loss: 0.0078
# Epoch 391/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 392/500, Train Loss: 0.0080, Validation Loss: 0.0074
# Epoch 393/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 394/500, Train Loss: 0.0081, Validation Loss: 0.0071
# Epoch 395/500, Train Loss: 0.0082, Validation Loss: 0.0077
# Epoch 396/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 397/500, Train Loss: 0.0080, Validation Loss: 0.0075
# Epoch 398/500, Train Loss: 0.0081, Validation Loss: 0.0071
# Epoch 399/500, Train Loss: 0.0082, Validation Loss: 0.0078
# Epoch 400/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 401/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 402/500, Train Loss: 0.0080, Validation Loss: 0.0076
# Epoch 403/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 404/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 405/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 406/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 407/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 408/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 409/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 410/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 411/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 412/500, Train Loss: 0.0080, Validation Loss: 0.0074
# Epoch 413/500, Train Loss: 0.0080, Validation Loss: 0.0075
# Epoch 414/500, Train Loss: 0.0082, Validation Loss: 0.0082
# Epoch 415/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 416/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 417/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 418/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 419/500, Train Loss: 0.0080, Validation Loss: 0.0074
# Epoch 420/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 421/500, Train Loss: 0.0082, Validation Loss: 0.0071
# Epoch 422/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 423/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 424/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 425/500, Train Loss: 0.0081, Validation Loss: 0.0071
# Epoch 426/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 427/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 428/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 429/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 430/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 431/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 432/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 433/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 434/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 435/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 436/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 437/500, Train Loss: 0.0080, Validation Loss: 0.0076
# Epoch 438/500, Train Loss: 0.0081, Validation Loss: 0.0078
# Epoch 439/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 440/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 441/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 442/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 443/500, Train Loss: 0.0080, Validation Loss: 0.0071
# Epoch 444/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 445/500, Train Loss: 0.0082, Validation Loss: 0.0078
# Epoch 446/500, Train Loss: 0.0080, Validation Loss: 0.0075
# Epoch 447/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 448/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 449/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 450/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 451/500, Train Loss: 0.0080, Validation Loss: 0.0070
# Epoch 452/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 453/500, Train Loss: 0.0082, Validation Loss: 0.0082
# Epoch 454/500, Train Loss: 0.0082, Validation Loss: 0.0072
# Epoch 455/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 456/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 457/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 458/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 459/500, Train Loss: 0.0082, Validation Loss: 0.0078
# Epoch 460/500, Train Loss: 0.0080, Validation Loss: 0.0075
# Epoch 461/500, Train Loss: 0.0081, Validation Loss: 0.0079
# Epoch 462/500, Train Loss: 0.0081, Validation Loss: 0.0075
# Epoch 463/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 464/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 465/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 466/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 467/500, Train Loss: 0.0080, Validation Loss: 0.0071
# Epoch 468/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 469/500, Train Loss: 0.0080, Validation Loss: 0.0074
# Epoch 470/500, Train Loss: 0.0082, Validation Loss: 0.0073
# Epoch 471/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 472/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 473/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 474/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 475/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 476/500, Train Loss: 0.0080, Validation Loss: 0.0071
# Epoch 477/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 478/500, Train Loss: 0.0080, Validation Loss: 0.0074
# Epoch 479/500, Train Loss: 0.0081, Validation Loss: 0.0071
# Epoch 480/500, Train Loss: 0.0080, Validation Loss: 0.0071
# Epoch 481/500, Train Loss: 0.0080, Validation Loss: 0.0075
# Epoch 482/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 483/500, Train Loss: 0.0080, Validation Loss: 0.0075
# Epoch 484/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 485/500, Train Loss: 0.0080, Validation Loss: 0.0075
# Epoch 486/500, Train Loss: 0.0080, Validation Loss: 0.0077
# Epoch 487/500, Train Loss: 0.0081, Validation Loss: 0.0072
# Epoch 488/500, Train Loss: 0.0081, Validation Loss: 0.0074
# Epoch 489/500, Train Loss: 0.0082, Validation Loss: 0.0075
# Epoch 490/500, Train Loss: 0.0080, Validation Loss: 0.0073
# Epoch 491/500, Train Loss: 0.0080, Validation Loss: 0.0071
# Epoch 492/500, Train Loss: 0.0080, Validation Loss: 0.0072
# Epoch 493/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 494/500, Train Loss: 0.0080, Validation Loss: 0.0071
# Epoch 495/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 496/500, Train Loss: 0.0081, Validation Loss: 0.0077
# Epoch 497/500, Train Loss: 0.0081, Validation Loss: 0.0076
# Epoch 498/500, Train Loss: 0.0081, Validation Loss: 0.0073
# Epoch 499/500, Train Loss: 0.0081, Validation Loss: 0.0071
# Epoch 500/500, Train Loss: 0.0081, Validation Loss: 0.0072

# %%
# Evaluate the final model on the test data
model.eval()  # Set the model to evaluation mode
test_loss = 0
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        predicted_final_state = model(initial_sample.unsqueeze(1))
        loss = loss_fn(predicted_final_state, final_sample.unsqueeze(1))
        test_loss += loss.item()

print(f'Test Loss: {test_loss/len(test_loader):.4f}')
# Out:
# Test Loss: 0.0075

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Visualize predictions on the test set
def plot_3d_slice(predicted, ground_truth, sample_index=0, slice_index=15):
    predicted_slice = predicted[sample_index, 0, slice_index, :, :].detach().cpu().numpy()  # For predicted tensor with channel dimension
    ground_truth_slice = ground_truth[sample_index, slice_index, :, :].detach().cpu().numpy()  # For ground truth tensor without channel dimension

    # Plotting
    fig, ax = plt.subplots(1, 2, figsize=(12, 6))
    ax[0].imshow(predicted_slice, cmap='hot', interpolation='nearest')
    ax[0].set_title("Predicted")
    ax[0].axis('off')

    ax[1].imshow(ground_truth_slice, cmap='hot', interpolation='nearest')
    ax[1].set_title("Ground Truth")
    ax[1].axis('off')

    plt.show()

# Example usage with a sample index of 0 and a slice index of 15
model.eval()
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        predicted_final_state = model(initial_sample.unsqueeze(1))

        # Visualize the first sample and slice
        plot_3d_slice(predicted_final_state, final_sample, sample_index=0, slice_index=15)
        break  # Just plot one batch for demonstration

# %%
# !pip install pytorch-msssim
# Out:
# Requirement already satisfied: pytorch-msssim in /home/wfarz001/envs/default-pytorch-gpu-2.1.0/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from pytorch-msssim) (2.1.0+cu118)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.12.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (2023.4.0)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->pytorch-msssim) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->pytorch-msssim) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
def rmse(predictions, targets):
    return torch.sqrt(torch.mean((predictions - targets) ** 2))

def mae(predictions, targets):
    return torch.mean(torch.abs(predictions - targets))

from sklearn.metrics import r2_score

def r2_score_pytorch(predictions, targets):
    predictions = predictions.detach().cpu().numpy()  # Convert to numpy
    targets = targets.detach().cpu().numpy()
    return r2_score(targets.flatten(), predictions.flatten())

def psnr(predictions, targets, max_pixel=1.0):
    mse = torch.mean((predictions - targets) ** 2)
    psnr_value = 20 * torch.log10(max_pixel / torch.sqrt(mse))
    return psnr_value

from pytorch_msssim import ssim

def compute_ssim(predictions, targets):
    return ssim(predictions, targets)

def dice_coefficient(predictions, targets, threshold=0.5):
    # Convert to binary masks based on the threshold
    predictions = predictions > threshold
    targets = targets > threshold
    intersection = torch.sum(predictions * targets)
    union = torch.sum(predictions) + torch.sum(targets)
    return (2 * intersection + 1e-6) / (union + 1e-6)

def mape(predictions, targets):
    return torch.mean(torch.abs((predictions - targets) / targets)) * 100

# %%
from sklearn.metrics import r2_score

# Initialize the metrics
rmse_vals = []
mae_vals = []
r2_vals = []
psnr_vals = []
ssim_vals = []
dsc_vals = []
mape_vals = []

model.eval()  # Set the model to evaluation mode
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        
        predicted_final_state = model(initial_sample.unsqueeze(1))  # Add channel dimension (1 for grayscale)

        # Calculate each metric
        rmse_vals.append(rmse(predicted_final_state, final_sample.unsqueeze(1)).item())
        mae_vals.append(mae(predicted_final_state, final_sample.unsqueeze(1)).item())
        r2_vals.append(r2_score_pytorch(predicted_final_state, final_sample.unsqueeze(1)))
        psnr_vals.append(psnr(predicted_final_state, final_sample.unsqueeze(1)).item())
        ssim_vals.append(compute_ssim(predicted_final_state, final_sample.unsqueeze(1)).item())
        dsc_vals.append(dice_coefficient(predicted_final_state, final_sample.unsqueeze(1)).item())
        mape_vals.append(mape(predicted_final_state, final_sample.unsqueeze(1)).item())

# Average the results over the test set
print(f"Average RMSE: {torch.mean(torch.tensor(rmse_vals))}")
print(f"Average MAE: {torch.mean(torch.tensor(mae_vals))}")
print(f"Average R² Score: {torch.mean(torch.tensor(r2_vals))}")
print(f"Average PSNR: {torch.mean(torch.tensor(psnr_vals))}")
print(f"Average SSIM: {torch.mean(torch.tensor(ssim_vals))}")
print(f"Average Dice Similarity Coefficient: {torch.mean(torch.tensor(dsc_vals))}")
print(f"Average MAPE: {torch.mean(torch.tensor(mape_vals))}%")
# Out:
# Average RMSE: 0.037948980927467346
# Average MAE: 0.007481400854885578
# Average R² Score: 0.7801546219302686
# Average PSNR: 28.745532989501953
# Average SSIM: 0.9994791746139526
# Average Dice Similarity Coefficient: 0.5556589961051941
# Average MAPE: 5.746256705632588e+22%
