# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>1.20.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics) (1.24.3)
# Requirement already satisfied: packaging>17.1 in /opt/conda/lib/python3.10/site-packages (from torchmetrics) (23.1)
# Requirement already satisfied: torch>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics) (2.1.0+cu118)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: setuptools in /home/wfarz001/envs/default-pytorch-gpu-2.1.0/lib/python3.10/site-packages (from lightning-utilities>=0.8.0->torchmetrics) (69.5.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.6.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (3.12.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (3.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (2023.4.0)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->torchmetrics) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.0.0->torchmetrics) (1.3.0)
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 18.9 MB/s eta 0:00:0000:01
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.11.9 torchmetrics-1.6.0
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from skimage.metrics import structural_similarity as ssim
import pandas as pd
import pytorch_ssim

# %%
from torchmetrics.functional import structural_similarity_index_measure

def ssim_loss(pred, target):
    return 1 - structural_similarity_index_measure(pred, target, data_range=1.0)  # For normalized inputs

# %%
def combined_loss(pred, target, alpha=0.5):
    mse = torch.nn.functional.mse_loss(pred, target)
    ssim = ssim_loss(pred, target)
    return alpha * mse + (1 - alpha) * ssim

# %%
# Paths to the data
initial_samples_folder = '/home/wfarz001/Fall-2024_Project/Tumor_States/Initial/'
final_samples_folder = '/home/wfarz001/Fall-2024_Project/Tumor_States/Final/'

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

class TumorDataset(Dataset):
    def __init__(self, initial_dir, final_dir, transform=None):
        self.initial_dir = initial_dir
        self.final_dir = final_dir
        self.transform = transform
        self.initial_files = sorted(os.listdir(initial_dir))  # List of initial state files
        self.final_files = sorted(os.listdir(final_dir))  # List of final state files
        
    def __len__(self):
        return len(self.initial_files)
    
    def __getitem__(self, idx):
        initial_file = os.path.join(self.initial_dir, self.initial_files[idx])
        final_file = os.path.join(self.final_dir, self.final_files[idx])
        
        initial_sample = np.load(initial_file)  # Assuming .npy format
        final_sample = np.load(final_file)  # Assuming .npy format
        
        # Convert to torch tensors
        initial_sample = torch.tensor(initial_sample, dtype=torch.float32)
        final_sample = torch.tensor(final_sample, dtype=torch.float32)
        
        if self.transform:
            initial_sample = self.transform(initial_sample)
            final_sample = self.transform(final_sample)
        
        return initial_sample, final_sample

# Create dataset and split it into train, validation, and test
dataset = TumorDataset(initial_samples_folder, final_samples_folder)
train_data, test_data = train_test_split(dataset, test_size=0.3, random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42)

train_loader = DataLoader(train_data, batch_size=4, shuffle=True)
val_loader = DataLoader(val_data, batch_size=4, shuffle=False)
test_loader = DataLoader(test_data, batch_size=4, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class TumorGrowthCNN(nn.Module):
    def __init__(self):
        super(TumorGrowthCNN, self).__init__()
        # Expect 1 input channel (after adding channel dimension)
        self.conv1 = nn.Conv3d(1, 16, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm3d(16)
        self.conv2 = nn.Conv3d(16, 32, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm3d(32)
        self.conv3 = nn.Conv3d(32, 64, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm3d(64)
        self.conv4 = nn.Conv3d(64, 1, kernel_size=1)  # Output: 1 channel

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.conv4(x)
        return x

# %%
# Initialize dataset and dataloaders
dataset = TumorDataset(initial_samples_folder, final_samples_folder)
train_loader = DataLoader(train_data, batch_size=4, shuffle=True)
val_loader = DataLoader(val_data, batch_size=4, shuffle=False)
test_loader = DataLoader(test_data, batch_size=4, shuffle=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize the model, optimizer, and loss function
model = TumorGrowthCNN().to(device)  # Ensure to place model on GPU if available
optimizer = optim.Adam(model.parameters(), lr=1e-4)
#loss_fn = combined_loss()

# Training loop with validation
num_epochs = 500
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for initial_sample, final_sample in train_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)

       # initial_sample= torch.clamp(initial_sample, 0, 1)
       # final_sample= torch.clamp(final_sample, 0, 1)
        
        optimizer.zero_grad()
        predicted_final_state = model(initial_sample.unsqueeze(1))  # Add channel dimension (1 for grayscale)
        
        # Compute loss and backpropagate
        loss = combined_loss(predicted_final_state, final_sample.unsqueeze(1))
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # Validation phase after each epoch
    model.eval()  # Set the model to evaluation mode
    val_loss = 0
    with torch.no_grad():
        for initial_sample, final_sample in val_loader:
            initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
            predicted_final_state = model(initial_sample.unsqueeze(1))
            loss = combined_loss(predicted_final_state, final_sample.unsqueeze(1))
            val_loss += loss.item()

    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {total_loss/len(train_loader):.4f}, Validation Loss: {val_loss/len(val_loader):.4f}')
# Out:
# /home/wfarz001/envs/default-pytorch-gpu-2.1.0/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:70: FutureWarning: Importing `spectral_angle_mapper` from `torchmetrics.functional` was deprecated and will be removed in 2.0. Import `spectral_angle_mapper` from `torchmetrics.image` instead.
#   _future_warning(
# Epoch 1/500, Train Loss: 0.2156, Validation Loss: 0.0620
# Epoch 2/500, Train Loss: 0.0576, Validation Loss: 0.0584
# Epoch 3/500, Train Loss: 0.0454, Validation Loss: 0.0739
# Epoch 4/500, Train Loss: 0.0410, Validation Loss: 0.0356
# Epoch 5/500, Train Loss: 0.0392, Validation Loss: 0.0446
# Epoch 6/500, Train Loss: 0.0384, Validation Loss: 0.0322
# Epoch 7/500, Train Loss: 0.0369, Validation Loss: 0.0327
# Epoch 8/500, Train Loss: 0.0351, Validation Loss: 0.0315
# Epoch 9/500, Train Loss: 0.0353, Validation Loss: 0.0333
# Epoch 10/500, Train Loss: 0.0355, Validation Loss: 0.0310
# Epoch 11/500, Train Loss: 0.0356, Validation Loss: 0.0397
# Epoch 12/500, Train Loss: 0.0349, Validation Loss: 0.0505
# Epoch 13/500, Train Loss: 0.0351, Validation Loss: 0.0361
# Epoch 14/500, Train Loss: 0.0331, Validation Loss: 0.0376
# Epoch 15/500, Train Loss: 0.0320, Validation Loss: 0.0292
# Epoch 16/500, Train Loss: 0.0329, Validation Loss: 0.0284
# Epoch 17/500, Train Loss: 0.0328, Validation Loss: 0.0326
# Epoch 18/500, Train Loss: 0.0330, Validation Loss: 0.0328
# Epoch 19/500, Train Loss: 0.0329, Validation Loss: 0.0331
# Epoch 20/500, Train Loss: 0.0331, Validation Loss: 0.0302
# Epoch 21/500, Train Loss: 0.0323, Validation Loss: 0.0298
# Epoch 22/500, Train Loss: 0.0326, Validation Loss: 0.0325
# Epoch 23/500, Train Loss: 0.0326, Validation Loss: 0.0288
# Epoch 24/500, Train Loss: 0.0320, Validation Loss: 0.0385
# Epoch 25/500, Train Loss: 0.0325, Validation Loss: 0.0356
# Epoch 26/500, Train Loss: 0.0338, Validation Loss: 0.0328
# Epoch 27/500, Train Loss: 0.0326, Validation Loss: 0.0281
# Epoch 28/500, Train Loss: 0.0322, Validation Loss: 0.0284
# Epoch 29/500, Train Loss: 0.0324, Validation Loss: 0.0273
# Epoch 30/500, Train Loss: 0.0314, Validation Loss: 0.0299
# Epoch 31/500, Train Loss: 0.0316, Validation Loss: 0.0283
# Epoch 32/500, Train Loss: 0.0317, Validation Loss: 0.0298
# Epoch 33/500, Train Loss: 0.0334, Validation Loss: 0.0270
# Epoch 34/500, Train Loss: 0.0319, Validation Loss: 0.0265
# Epoch 35/500, Train Loss: 0.0309, Validation Loss: 0.0599
# Epoch 36/500, Train Loss: 0.0315, Validation Loss: 0.0298
# Epoch 37/500, Train Loss: 0.0312, Validation Loss: 0.0275
# Epoch 38/500, Train Loss: 0.0316, Validation Loss: 0.0384
# Epoch 39/500, Train Loss: 0.0306, Validation Loss: 0.0308
# Epoch 40/500, Train Loss: 0.0306, Validation Loss: 0.0453
# Epoch 41/500, Train Loss: 0.0340, Validation Loss: 0.0401
# Epoch 42/500, Train Loss: 0.0318, Validation Loss: 0.0289
# Epoch 43/500, Train Loss: 0.0306, Validation Loss: 0.0399
# Epoch 44/500, Train Loss: 0.0311, Validation Loss: 0.0474
# Epoch 45/500, Train Loss: 0.0308, Validation Loss: 0.0276
# Epoch 46/500, Train Loss: 0.0318, Validation Loss: 0.0297
# Epoch 47/500, Train Loss: 0.0316, Validation Loss: 0.0374
# Epoch 48/500, Train Loss: 0.0308, Validation Loss: 0.0344
# Epoch 49/500, Train Loss: 0.0307, Validation Loss: 0.0282
# Epoch 50/500, Train Loss: 0.0304, Validation Loss: 0.0467
# Epoch 51/500, Train Loss: 0.0317, Validation Loss: 0.0295
# Epoch 52/500, Train Loss: 0.0322, Validation Loss: 0.0382
# Epoch 53/500, Train Loss: 0.0312, Validation Loss: 0.0287
# Epoch 54/500, Train Loss: 0.0313, Validation Loss: 0.0280
# Epoch 55/500, Train Loss: 0.0309, Validation Loss: 0.0268
# Epoch 56/500, Train Loss: 0.0302, Validation Loss: 0.0268
# Epoch 57/500, Train Loss: 0.0314, Validation Loss: 0.0384
# Epoch 58/500, Train Loss: 0.0316, Validation Loss: 0.0347
# Epoch 59/500, Train Loss: 0.0310, Validation Loss: 0.0278
# Epoch 60/500, Train Loss: 0.0306, Validation Loss: 0.0271
# Epoch 61/500, Train Loss: 0.0305, Validation Loss: 0.0272
# Epoch 62/500, Train Loss: 0.0308, Validation Loss: 0.0364
# Epoch 63/500, Train Loss: 0.0319, Validation Loss: 0.0271
# Epoch 64/500, Train Loss: 0.0304, Validation Loss: 0.0290
# Epoch 65/500, Train Loss: 0.0305, Validation Loss: 0.0326
# Epoch 66/500, Train Loss: 0.0302, Validation Loss: 0.0379
# Epoch 67/500, Train Loss: 0.0323, Validation Loss: 0.0273
# Epoch 68/500, Train Loss: 0.0307, Validation Loss: 0.0270
# Epoch 69/500, Train Loss: 0.0302, Validation Loss: 0.0476
# Epoch 70/500, Train Loss: 0.0307, Validation Loss: 0.0476
# Epoch 71/500, Train Loss: 0.0307, Validation Loss: 0.0279
# Epoch 72/500, Train Loss: 0.0301, Validation Loss: 0.0271
# Epoch 73/500, Train Loss: 0.0298, Validation Loss: 0.0587
# Epoch 74/500, Train Loss: 0.0301, Validation Loss: 0.0278
# Epoch 75/500, Train Loss: 0.0306, Validation Loss: 0.0268
# Epoch 76/500, Train Loss: 0.0310, Validation Loss: 0.0262
# Epoch 77/500, Train Loss: 0.0303, Validation Loss: 0.0350
# Epoch 78/500, Train Loss: 0.0310, Validation Loss: 0.0453
# Epoch 79/500, Train Loss: 0.0307, Validation Loss: 0.0291
# Epoch 80/500, Train Loss: 0.0309, Validation Loss: 0.0396
# Epoch 81/500, Train Loss: 0.0303, Validation Loss: 0.0387
# Epoch 82/500, Train Loss: 0.0305, Validation Loss: 0.0318
# Epoch 83/500, Train Loss: 0.0309, Validation Loss: 0.0281
# Epoch 84/500, Train Loss: 0.0297, Validation Loss: 0.0332
# Epoch 85/500, Train Loss: 0.0308, Validation Loss: 0.0388
# Epoch 86/500, Train Loss: 0.0303, Validation Loss: 0.0276
# Epoch 87/500, Train Loss: 0.0302, Validation Loss: 0.0342
# Epoch 88/500, Train Loss: 0.0309, Validation Loss: 0.0346
# Epoch 89/500, Train Loss: 0.0308, Validation Loss: 0.0287
# Epoch 90/500, Train Loss: 0.0298, Validation Loss: 0.0271
# Epoch 91/500, Train Loss: 0.0304, Validation Loss: 0.0284
# Epoch 92/500, Train Loss: 0.0300, Validation Loss: 0.0303
# Epoch 93/500, Train Loss: 0.0300, Validation Loss: 0.0279
# Epoch 94/500, Train Loss: 0.0308, Validation Loss: 0.0331
# Epoch 95/500, Train Loss: 0.0304, Validation Loss: 0.0293
# Epoch 96/500, Train Loss: 0.0304, Validation Loss: 0.0267
# Epoch 97/500, Train Loss: 0.0304, Validation Loss: 0.0336
# Epoch 98/500, Train Loss: 0.0303, Validation Loss: 0.0312
# Epoch 99/500, Train Loss: 0.0300, Validation Loss: 0.0255
# Epoch 100/500, Train Loss: 0.0302, Validation Loss: 0.0275
# Epoch 101/500, Train Loss: 0.0321, Validation Loss: 0.0392
# Epoch 102/500, Train Loss: 0.0304, Validation Loss: 0.0305
# Epoch 103/500, Train Loss: 0.0306, Validation Loss: 0.0258
# Epoch 104/500, Train Loss: 0.0306, Validation Loss: 0.0349
# Epoch 105/500, Train Loss: 0.0309, Validation Loss: 0.0304
# Epoch 106/500, Train Loss: 0.0314, Validation Loss: 0.0266
# Epoch 107/500, Train Loss: 0.0301, Validation Loss: 0.0267
# Epoch 108/500, Train Loss: 0.0304, Validation Loss: 0.0297
# Epoch 109/500, Train Loss: 0.0302, Validation Loss: 0.0254
# Epoch 110/500, Train Loss: 0.0301, Validation Loss: 0.0274
# Epoch 111/500, Train Loss: 0.0311, Validation Loss: 0.0292
# Epoch 112/500, Train Loss: 0.0305, Validation Loss: 0.0415
# Epoch 113/500, Train Loss: 0.0296, Validation Loss: 0.0467
# Epoch 114/500, Train Loss: 0.0300, Validation Loss: 0.0640
# Epoch 115/500, Train Loss: 0.0310, Validation Loss: 0.0287
# Epoch 116/500, Train Loss: 0.0306, Validation Loss: 0.0270
# Epoch 117/500, Train Loss: 0.0308, Validation Loss: 0.0706
# Epoch 118/500, Train Loss: 0.0299, Validation Loss: 0.0332
# Epoch 119/500, Train Loss: 0.0299, Validation Loss: 0.0271
# Epoch 120/500, Train Loss: 0.0297, Validation Loss: 0.0264
# Epoch 121/500, Train Loss: 0.0300, Validation Loss: 0.0280
# Epoch 122/500, Train Loss: 0.0302, Validation Loss: 0.0281
# Epoch 123/500, Train Loss: 0.0305, Validation Loss: 0.0259
# Epoch 124/500, Train Loss: 0.0308, Validation Loss: 0.0520
# Epoch 125/500, Train Loss: 0.0299, Validation Loss: 0.0256
# Epoch 126/500, Train Loss: 0.0298, Validation Loss: 0.0266
# Epoch 127/500, Train Loss: 0.0301, Validation Loss: 0.0271
# Epoch 128/500, Train Loss: 0.0301, Validation Loss: 0.0275
# Epoch 129/500, Train Loss: 0.0297, Validation Loss: 0.0266
# Epoch 130/500, Train Loss: 0.0303, Validation Loss: 0.0364
# Epoch 131/500, Train Loss: 0.0304, Validation Loss: 0.0283
# Epoch 132/500, Train Loss: 0.0300, Validation Loss: 0.0359
# Epoch 133/500, Train Loss: 0.0302, Validation Loss: 0.0265
# Epoch 134/500, Train Loss: 0.0299, Validation Loss: 0.0323
# Epoch 135/500, Train Loss: 0.0296, Validation Loss: 0.0271
# Epoch 136/500, Train Loss: 0.0302, Validation Loss: 0.0274
# Epoch 137/500, Train Loss: 0.0317, Validation Loss: 0.0312
# Epoch 138/500, Train Loss: 0.0295, Validation Loss: 0.0259
# Epoch 139/500, Train Loss: 0.0298, Validation Loss: 0.0278
# Epoch 140/500, Train Loss: 0.0298, Validation Loss: 0.0287
# Epoch 141/500, Train Loss: 0.0299, Validation Loss: 0.0266
# Epoch 142/500, Train Loss: 0.0305, Validation Loss: 0.0317
# Epoch 143/500, Train Loss: 0.0298, Validation Loss: 0.0273
# Epoch 144/500, Train Loss: 0.0308, Validation Loss: 0.0290
# Epoch 145/500, Train Loss: 0.0301, Validation Loss: 0.0256
# Epoch 146/500, Train Loss: 0.0303, Validation Loss: 0.0353
# Epoch 147/500, Train Loss: 0.0300, Validation Loss: 0.0310
# Epoch 148/500, Train Loss: 0.0305, Validation Loss: 0.0405
# Epoch 149/500, Train Loss: 0.0303, Validation Loss: 0.0351
# Epoch 150/500, Train Loss: 0.0296, Validation Loss: 0.0275
# Epoch 151/500, Train Loss: 0.0307, Validation Loss: 0.0287
# Epoch 152/500, Train Loss: 0.0302, Validation Loss: 0.0286
# Epoch 153/500, Train Loss: 0.0298, Validation Loss: 0.0279
# Epoch 154/500, Train Loss: 0.0305, Validation Loss: 0.0288
# Epoch 155/500, Train Loss: 0.0297, Validation Loss: 0.0257
# Epoch 156/500, Train Loss: 0.0300, Validation Loss: 0.0305
# Epoch 157/500, Train Loss: 0.0298, Validation Loss: 0.0260
# Epoch 158/500, Train Loss: 0.0298, Validation Loss: 0.0257
# Epoch 159/500, Train Loss: 0.0298, Validation Loss: 0.0288
# Epoch 160/500, Train Loss: 0.0297, Validation Loss: 0.0274
# Epoch 161/500, Train Loss: 0.0296, Validation Loss: 0.0266
# Epoch 162/500, Train Loss: 0.0304, Validation Loss: 0.0277
# Epoch 163/500, Train Loss: 0.0298, Validation Loss: 0.0381
# Epoch 164/500, Train Loss: 0.0310, Validation Loss: 0.0377
# Epoch 165/500, Train Loss: 0.0302, Validation Loss: 0.0291
# Epoch 166/500, Train Loss: 0.0311, Validation Loss: 0.0366
# Epoch 167/500, Train Loss: 0.0301, Validation Loss: 0.0368
# Epoch 168/500, Train Loss: 0.0300, Validation Loss: 0.0340
# Epoch 169/500, Train Loss: 0.0301, Validation Loss: 0.0260
# Epoch 170/500, Train Loss: 0.0297, Validation Loss: 0.0263
# Epoch 171/500, Train Loss: 0.0308, Validation Loss: 0.0267
# Epoch 172/500, Train Loss: 0.0302, Validation Loss: 0.0274
# Epoch 173/500, Train Loss: 0.0302, Validation Loss: 0.0332
# Epoch 174/500, Train Loss: 0.0303, Validation Loss: 0.0300
# Epoch 175/500, Train Loss: 0.0300, Validation Loss: 0.0281
# Epoch 176/500, Train Loss: 0.0294, Validation Loss: 0.0258
# Epoch 177/500, Train Loss: 0.0298, Validation Loss: 0.0267
# Epoch 178/500, Train Loss: 0.0293, Validation Loss: 0.0266
# Epoch 179/500, Train Loss: 0.0302, Validation Loss: 0.0323
# Epoch 180/500, Train Loss: 0.0297, Validation Loss: 0.0267
# Epoch 181/500, Train Loss: 0.0295, Validation Loss: 0.0351
# Epoch 182/500, Train Loss: 0.0301, Validation Loss: 0.0367
# Epoch 183/500, Train Loss: 0.0297, Validation Loss: 0.0257
# Epoch 184/500, Train Loss: 0.0302, Validation Loss: 0.0266
# Epoch 185/500, Train Loss: 0.0300, Validation Loss: 0.0262
# Epoch 186/500, Train Loss: 0.0296, Validation Loss: 0.0276
# Epoch 187/500, Train Loss: 0.0295, Validation Loss: 0.0263
# Epoch 188/500, Train Loss: 0.0303, Validation Loss: 0.0266
# Epoch 189/500, Train Loss: 0.0295, Validation Loss: 0.0423
# Epoch 190/500, Train Loss: 0.0297, Validation Loss: 0.0300
# Epoch 191/500, Train Loss: 0.0302, Validation Loss: 0.0276
# Epoch 192/500, Train Loss: 0.0297, Validation Loss: 0.0343
# Epoch 193/500, Train Loss: 0.0300, Validation Loss: 0.0274
# Epoch 194/500, Train Loss: 0.0305, Validation Loss: 0.0280
# Epoch 195/500, Train Loss: 0.0298, Validation Loss: 0.0262
# Epoch 196/500, Train Loss: 0.0296, Validation Loss: 0.0259
# Epoch 197/500, Train Loss: 0.0305, Validation Loss: 0.0282
# Epoch 198/500, Train Loss: 0.0305, Validation Loss: 0.0281
# Epoch 199/500, Train Loss: 0.0296, Validation Loss: 0.0302
# Epoch 200/500, Train Loss: 0.0298, Validation Loss: 0.0281
# Epoch 201/500, Train Loss: 0.0296, Validation Loss: 0.0293
# Epoch 202/500, Train Loss: 0.0303, Validation Loss: 0.0384
# Epoch 203/500, Train Loss: 0.0304, Validation Loss: 0.0380
# Epoch 204/500, Train Loss: 0.0298, Validation Loss: 0.0270
# Epoch 205/500, Train Loss: 0.0300, Validation Loss: 0.0257
# Epoch 206/500, Train Loss: 0.0302, Validation Loss: 0.0277
# Epoch 207/500, Train Loss: 0.0295, Validation Loss: 0.0273
# Epoch 208/500, Train Loss: 0.0298, Validation Loss: 0.0263
# Epoch 209/500, Train Loss: 0.0300, Validation Loss: 0.0286
# Epoch 210/500, Train Loss: 0.0295, Validation Loss: 0.0271
# Epoch 211/500, Train Loss: 0.0296, Validation Loss: 0.0265
# Epoch 212/500, Train Loss: 0.0299, Validation Loss: 0.0302
# Epoch 213/500, Train Loss: 0.0302, Validation Loss: 0.0266
# Epoch 214/500, Train Loss: 0.0297, Validation Loss: 0.0259
# Epoch 215/500, Train Loss: 0.0299, Validation Loss: 0.0261
# Epoch 216/500, Train Loss: 0.0299, Validation Loss: 0.0309
# Epoch 217/500, Train Loss: 0.0299, Validation Loss: 0.0444
# Epoch 218/500, Train Loss: 0.0299, Validation Loss: 0.0257
# Epoch 219/500, Train Loss: 0.0295, Validation Loss: 0.0256
# Epoch 220/500, Train Loss: 0.0295, Validation Loss: 0.0289
# Epoch 221/500, Train Loss: 0.0295, Validation Loss: 0.0260
# Epoch 222/500, Train Loss: 0.0304, Validation Loss: 0.0284
# Epoch 223/500, Train Loss: 0.0297, Validation Loss: 0.0303
# Epoch 224/500, Train Loss: 0.0293, Validation Loss: 0.0258
# Epoch 225/500, Train Loss: 0.0297, Validation Loss: 0.0260
# Epoch 226/500, Train Loss: 0.0294, Validation Loss: 0.0266
# Epoch 227/500, Train Loss: 0.0298, Validation Loss: 0.0292
# Epoch 228/500, Train Loss: 0.0298, Validation Loss: 0.0351
# Epoch 229/500, Train Loss: 0.0304, Validation Loss: 0.0272
# Epoch 230/500, Train Loss: 0.0298, Validation Loss: 0.0269
# Epoch 231/500, Train Loss: 0.0294, Validation Loss: 0.0340
# Epoch 232/500, Train Loss: 0.0300, Validation Loss: 0.0271
# Epoch 233/500, Train Loss: 0.0295, Validation Loss: 0.0263
# Epoch 234/500, Train Loss: 0.0299, Validation Loss: 0.0303
# Epoch 235/500, Train Loss: 0.0297, Validation Loss: 0.0266
# Epoch 236/500, Train Loss: 0.0293, Validation Loss: 0.0263
# Epoch 237/500, Train Loss: 0.0298, Validation Loss: 0.0294
# Epoch 238/500, Train Loss: 0.0298, Validation Loss: 0.0309
# Epoch 239/500, Train Loss: 0.0298, Validation Loss: 0.0267
# Epoch 240/500, Train Loss: 0.0297, Validation Loss: 0.0278
# Epoch 241/500, Train Loss: 0.0298, Validation Loss: 0.0371
# Epoch 242/500, Train Loss: 0.0298, Validation Loss: 0.0291
# Epoch 243/500, Train Loss: 0.0300, Validation Loss: 0.0291
# Epoch 244/500, Train Loss: 0.0296, Validation Loss: 0.0276
# Epoch 245/500, Train Loss: 0.0296, Validation Loss: 0.0334
# Epoch 246/500, Train Loss: 0.0296, Validation Loss: 0.0260
# Epoch 247/500, Train Loss: 0.0294, Validation Loss: 0.0260
# Epoch 248/500, Train Loss: 0.0295, Validation Loss: 0.0270
# Epoch 249/500, Train Loss: 0.0296, Validation Loss: 0.0303
# Epoch 250/500, Train Loss: 0.0296, Validation Loss: 0.0266
# Epoch 251/500, Train Loss: 0.0296, Validation Loss: 0.0270
# Epoch 252/500, Train Loss: 0.0302, Validation Loss: 0.0263
# Epoch 253/500, Train Loss: 0.0294, Validation Loss: 0.0262
# Epoch 254/500, Train Loss: 0.0294, Validation Loss: 0.0297
# Epoch 255/500, Train Loss: 0.0295, Validation Loss: 0.0437
# Epoch 256/500, Train Loss: 0.0298, Validation Loss: 0.0266
# Epoch 257/500, Train Loss: 0.0297, Validation Loss: 0.0272
# Epoch 258/500, Train Loss: 0.0296, Validation Loss: 0.0267
# Epoch 259/500, Train Loss: 0.0297, Validation Loss: 0.0309
# Epoch 260/500, Train Loss: 0.0296, Validation Loss: 0.0267
# Epoch 261/500, Train Loss: 0.0298, Validation Loss: 0.0272
# Epoch 262/500, Train Loss: 0.0296, Validation Loss: 0.0261
# Epoch 263/500, Train Loss: 0.0298, Validation Loss: 0.0261
# Epoch 264/500, Train Loss: 0.0293, Validation Loss: 0.0259
# Epoch 265/500, Train Loss: 0.0303, Validation Loss: 0.0276
# Epoch 266/500, Train Loss: 0.0300, Validation Loss: 0.0400
# Epoch 267/500, Train Loss: 0.0295, Validation Loss: 0.0301
# Epoch 268/500, Train Loss: 0.0298, Validation Loss: 0.0317
# Epoch 269/500, Train Loss: 0.0301, Validation Loss: 0.0317
# Epoch 270/500, Train Loss: 0.0297, Validation Loss: 0.0270
# Epoch 271/500, Train Loss: 0.0294, Validation Loss: 0.0305
# Epoch 272/500, Train Loss: 0.0295, Validation Loss: 0.0275
# Epoch 273/500, Train Loss: 0.0298, Validation Loss: 0.0261
# Epoch 274/500, Train Loss: 0.0297, Validation Loss: 0.0265
# Epoch 275/500, Train Loss: 0.0294, Validation Loss: 0.0266
# Epoch 276/500, Train Loss: 0.0295, Validation Loss: 0.0259
# Epoch 277/500, Train Loss: 0.0295, Validation Loss: 0.0273
# Epoch 278/500, Train Loss: 0.0295, Validation Loss: 0.0260
# Epoch 279/500, Train Loss: 0.0295, Validation Loss: 0.0274
# Epoch 280/500, Train Loss: 0.0295, Validation Loss: 0.0253
# Epoch 281/500, Train Loss: 0.0294, Validation Loss: 0.0265
# Epoch 282/500, Train Loss: 0.0296, Validation Loss: 0.0294
# Epoch 283/500, Train Loss: 0.0300, Validation Loss: 0.0262
# Epoch 284/500, Train Loss: 0.0295, Validation Loss: 0.0260
# Epoch 285/500, Train Loss: 0.0292, Validation Loss: 0.0280
# Epoch 286/500, Train Loss: 0.0299, Validation Loss: 0.0276
# Epoch 287/500, Train Loss: 0.0296, Validation Loss: 0.0292
# Epoch 288/500, Train Loss: 0.0297, Validation Loss: 0.0352
# Epoch 289/500, Train Loss: 0.0307, Validation Loss: 0.0335
# Epoch 290/500, Train Loss: 0.0298, Validation Loss: 0.0265
# Epoch 291/500, Train Loss: 0.0298, Validation Loss: 0.0271
# Epoch 292/500, Train Loss: 0.0295, Validation Loss: 0.0273
# Epoch 293/500, Train Loss: 0.0292, Validation Loss: 0.0302
# Epoch 294/500, Train Loss: 0.0295, Validation Loss: 0.0281
# Epoch 295/500, Train Loss: 0.0292, Validation Loss: 0.0269
# Epoch 296/500, Train Loss: 0.0299, Validation Loss: 0.0333
# Epoch 297/500, Train Loss: 0.0293, Validation Loss: 0.0271
# Epoch 298/500, Train Loss: 0.0296, Validation Loss: 0.0266
# Epoch 299/500, Train Loss: 0.0292, Validation Loss: 0.0258
# Epoch 300/500, Train Loss: 0.0293, Validation Loss: 0.0266
# Epoch 301/500, Train Loss: 0.0299, Validation Loss: 0.0344
# Epoch 302/500, Train Loss: 0.0298, Validation Loss: 0.0377
# Epoch 303/500, Train Loss: 0.0294, Validation Loss: 0.0311
# Epoch 304/500, Train Loss: 0.0293, Validation Loss: 0.0258
# Epoch 305/500, Train Loss: 0.0292, Validation Loss: 0.0267
# Epoch 306/500, Train Loss: 0.0301, Validation Loss: 0.0294
# Epoch 307/500, Train Loss: 0.0292, Validation Loss: 0.0263
# Epoch 308/500, Train Loss: 0.0297, Validation Loss: 0.0297
# Epoch 309/500, Train Loss: 0.0298, Validation Loss: 0.0271
# Epoch 310/500, Train Loss: 0.0294, Validation Loss: 0.0264
# Epoch 311/500, Train Loss: 0.0295, Validation Loss: 0.0276
# Epoch 312/500, Train Loss: 0.0294, Validation Loss: 0.0257
# Epoch 313/500, Train Loss: 0.0293, Validation Loss: 0.0270
# Epoch 314/500, Train Loss: 0.0292, Validation Loss: 0.0259
# Epoch 315/500, Train Loss: 0.0295, Validation Loss: 0.0259
# Epoch 316/500, Train Loss: 0.0297, Validation Loss: 0.0265
# Epoch 317/500, Train Loss: 0.0303, Validation Loss: 0.0493
# Epoch 318/500, Train Loss: 0.0295, Validation Loss: 0.0267
# Epoch 319/500, Train Loss: 0.0296, Validation Loss: 0.0261
# Epoch 320/500, Train Loss: 0.0292, Validation Loss: 0.0275
# Epoch 321/500, Train Loss: 0.0295, Validation Loss: 0.0310
# Epoch 322/500, Train Loss: 0.0296, Validation Loss: 0.0269
# Epoch 323/500, Train Loss: 0.0296, Validation Loss: 0.0272
# Epoch 324/500, Train Loss: 0.0297, Validation Loss: 0.0264
# Epoch 325/500, Train Loss: 0.0294, Validation Loss: 0.0287
# Epoch 326/500, Train Loss: 0.0294, Validation Loss: 0.0260
# Epoch 327/500, Train Loss: 0.0294, Validation Loss: 0.0257
# Epoch 328/500, Train Loss: 0.0294, Validation Loss: 0.0262
# Epoch 329/500, Train Loss: 0.0292, Validation Loss: 0.0284
# Epoch 330/500, Train Loss: 0.0293, Validation Loss: 0.0270
# Epoch 331/500, Train Loss: 0.0293, Validation Loss: 0.0259
# Epoch 332/500, Train Loss: 0.0293, Validation Loss: 0.0263
# Epoch 333/500, Train Loss: 0.0298, Validation Loss: 0.0324
# Epoch 334/500, Train Loss: 0.0294, Validation Loss: 0.0277
# Epoch 335/500, Train Loss: 0.0292, Validation Loss: 0.0264
# Epoch 336/500, Train Loss: 0.0293, Validation Loss: 0.0263
# Epoch 337/500, Train Loss: 0.0296, Validation Loss: 0.0290
# Epoch 338/500, Train Loss: 0.0295, Validation Loss: 0.0261
# Epoch 339/500, Train Loss: 0.0292, Validation Loss: 0.0258
# Epoch 340/500, Train Loss: 0.0294, Validation Loss: 0.0286
# Epoch 341/500, Train Loss: 0.0294, Validation Loss: 0.0278
# Epoch 342/500, Train Loss: 0.0295, Validation Loss: 0.0317
# Epoch 343/500, Train Loss: 0.0291, Validation Loss: 0.0264
# Epoch 344/500, Train Loss: 0.0295, Validation Loss: 0.0259
# Epoch 345/500, Train Loss: 0.0293, Validation Loss: 0.0256
# Epoch 346/500, Train Loss: 0.0295, Validation Loss: 0.0273
# Epoch 347/500, Train Loss: 0.0298, Validation Loss: 0.0283
# Epoch 348/500, Train Loss: 0.0294, Validation Loss: 0.0258
# Epoch 349/500, Train Loss: 0.0292, Validation Loss: 0.0259
# Epoch 350/500, Train Loss: 0.0293, Validation Loss: 0.0269
# Epoch 351/500, Train Loss: 0.0294, Validation Loss: 0.0268
# Epoch 352/500, Train Loss: 0.0295, Validation Loss: 0.0282
# Epoch 353/500, Train Loss: 0.0296, Validation Loss: 0.0279
# Epoch 354/500, Train Loss: 0.0296, Validation Loss: 0.0293
# Epoch 355/500, Train Loss: 0.0294, Validation Loss: 0.0284
# Epoch 356/500, Train Loss: 0.0294, Validation Loss: 0.0274
# Epoch 357/500, Train Loss: 0.0294, Validation Loss: 0.0282
# Epoch 358/500, Train Loss: 0.0293, Validation Loss: 0.0261
# Epoch 359/500, Train Loss: 0.0294, Validation Loss: 0.0264
# Epoch 360/500, Train Loss: 0.0293, Validation Loss: 0.0291
# Epoch 361/500, Train Loss: 0.0296, Validation Loss: 0.0279
# Epoch 362/500, Train Loss: 0.0297, Validation Loss: 0.0261
# Epoch 363/500, Train Loss: 0.0301, Validation Loss: 0.0316
# Epoch 364/500, Train Loss: 0.0293, Validation Loss: 0.0261
# Epoch 365/500, Train Loss: 0.0298, Validation Loss: 0.0262
# Epoch 366/500, Train Loss: 0.0295, Validation Loss: 0.0258
# Epoch 367/500, Train Loss: 0.0294, Validation Loss: 0.0261
# Epoch 368/500, Train Loss: 0.0292, Validation Loss: 0.0264
# Epoch 369/500, Train Loss: 0.0293, Validation Loss: 0.0255
# Epoch 370/500, Train Loss: 0.0292, Validation Loss: 0.0261
# Epoch 371/500, Train Loss: 0.0293, Validation Loss: 0.0259
# Epoch 372/500, Train Loss: 0.0291, Validation Loss: 0.0303
# Epoch 373/500, Train Loss: 0.0293, Validation Loss: 0.0260
# Epoch 374/500, Train Loss: 0.0294, Validation Loss: 0.0259
# Epoch 375/500, Train Loss: 0.0296, Validation Loss: 0.0265
# Epoch 376/500, Train Loss: 0.0290, Validation Loss: 0.0273
# Epoch 377/500, Train Loss: 0.0295, Validation Loss: 0.0278
# Epoch 378/500, Train Loss: 0.0293, Validation Loss: 0.0263
# Epoch 379/500, Train Loss: 0.0296, Validation Loss: 0.0259
# Epoch 380/500, Train Loss: 0.0292, Validation Loss: 0.0307
# Epoch 381/500, Train Loss: 0.0291, Validation Loss: 0.0262
# Epoch 382/500, Train Loss: 0.0291, Validation Loss: 0.0265
# Epoch 383/500, Train Loss: 0.0293, Validation Loss: 0.0266
# Epoch 384/500, Train Loss: 0.0294, Validation Loss: 0.0269
# Epoch 385/500, Train Loss: 0.0291, Validation Loss: 0.0286
# Epoch 386/500, Train Loss: 0.0291, Validation Loss: 0.0256
# Epoch 387/500, Train Loss: 0.0293, Validation Loss: 0.0265
# Epoch 388/500, Train Loss: 0.0295, Validation Loss: 0.0272
# Epoch 389/500, Train Loss: 0.0298, Validation Loss: 0.0259
# Epoch 390/500, Train Loss: 0.0293, Validation Loss: 0.0263
# Epoch 391/500, Train Loss: 0.0292, Validation Loss: 0.0261
# Epoch 392/500, Train Loss: 0.0293, Validation Loss: 0.0291
# Epoch 393/500, Train Loss: 0.0293, Validation Loss: 0.0271
# Epoch 394/500, Train Loss: 0.0294, Validation Loss: 0.0258
# Epoch 395/500, Train Loss: 0.0297, Validation Loss: 0.0302
# Epoch 396/500, Train Loss: 0.0295, Validation Loss: 0.0268
# Epoch 397/500, Train Loss: 0.0294, Validation Loss: 0.0260
# Epoch 398/500, Train Loss: 0.0293, Validation Loss: 0.0264
# Epoch 399/500, Train Loss: 0.0297, Validation Loss: 0.0272
# Epoch 400/500, Train Loss: 0.0296, Validation Loss: 0.0297
# Epoch 401/500, Train Loss: 0.0293, Validation Loss: 0.0270
# Epoch 402/500, Train Loss: 0.0292, Validation Loss: 0.0268
# Epoch 403/500, Train Loss: 0.0292, Validation Loss: 0.0262
# Epoch 404/500, Train Loss: 0.0293, Validation Loss: 0.0253
# Epoch 405/500, Train Loss: 0.0295, Validation Loss: 0.0256
# Epoch 406/500, Train Loss: 0.0296, Validation Loss: 0.0278
# Epoch 407/500, Train Loss: 0.0295, Validation Loss: 0.0263
# Epoch 408/500, Train Loss: 0.0294, Validation Loss: 0.0282
# Epoch 409/500, Train Loss: 0.0295, Validation Loss: 0.0314
# Epoch 410/500, Train Loss: 0.0292, Validation Loss: 0.0289
# Epoch 411/500, Train Loss: 0.0295, Validation Loss: 0.0268
# Epoch 412/500, Train Loss: 0.0296, Validation Loss: 0.0263
# Epoch 413/500, Train Loss: 0.0296, Validation Loss: 0.0354
# Epoch 414/500, Train Loss: 0.0294, Validation Loss: 0.0264
# Epoch 415/500, Train Loss: 0.0293, Validation Loss: 0.0322
# Epoch 416/500, Train Loss: 0.0293, Validation Loss: 0.0256
# Epoch 417/500, Train Loss: 0.0293, Validation Loss: 0.0290
# Epoch 418/500, Train Loss: 0.0292, Validation Loss: 0.0263
# Epoch 419/500, Train Loss: 0.0295, Validation Loss: 0.0260
# Epoch 420/500, Train Loss: 0.0297, Validation Loss: 0.0270
# Epoch 421/500, Train Loss: 0.0294, Validation Loss: 0.0258
# Epoch 422/500, Train Loss: 0.0294, Validation Loss: 0.0255
# Epoch 423/500, Train Loss: 0.0294, Validation Loss: 0.0260
# Epoch 424/500, Train Loss: 0.0294, Validation Loss: 0.0272
# Epoch 425/500, Train Loss: 0.0293, Validation Loss: 0.0279
# Epoch 426/500, Train Loss: 0.0291, Validation Loss: 0.0268
# Epoch 427/500, Train Loss: 0.0292, Validation Loss: 0.0259
# Epoch 428/500, Train Loss: 0.0293, Validation Loss: 0.0268
# Epoch 429/500, Train Loss: 0.0292, Validation Loss: 0.0256
# Epoch 430/500, Train Loss: 0.0292, Validation Loss: 0.0264
# Epoch 431/500, Train Loss: 0.0292, Validation Loss: 0.0259
# Epoch 432/500, Train Loss: 0.0295, Validation Loss: 0.0268
# Epoch 433/500, Train Loss: 0.0292, Validation Loss: 0.0258
# Epoch 434/500, Train Loss: 0.0294, Validation Loss: 0.0277
# Epoch 435/500, Train Loss: 0.0291, Validation Loss: 0.0264
# Epoch 436/500, Train Loss: 0.0293, Validation Loss: 0.0261
# Epoch 437/500, Train Loss: 0.0294, Validation Loss: 0.0270
# Epoch 438/500, Train Loss: 0.0292, Validation Loss: 0.0258
# Epoch 439/500, Train Loss: 0.0292, Validation Loss: 0.0256
# Epoch 440/500, Train Loss: 0.0292, Validation Loss: 0.0262
# Epoch 441/500, Train Loss: 0.0293, Validation Loss: 0.0284
# Epoch 442/500, Train Loss: 0.0292, Validation Loss: 0.0258
# Epoch 443/500, Train Loss: 0.0290, Validation Loss: 0.0264
# Epoch 444/500, Train Loss: 0.0291, Validation Loss: 0.0273
# Epoch 445/500, Train Loss: 0.0294, Validation Loss: 0.0256
# Epoch 446/500, Train Loss: 0.0293, Validation Loss: 0.0260
# Epoch 447/500, Train Loss: 0.0295, Validation Loss: 0.0303
# Epoch 448/500, Train Loss: 0.0293, Validation Loss: 0.0272
# Epoch 449/500, Train Loss: 0.0298, Validation Loss: 0.0265
# Epoch 450/500, Train Loss: 0.0291, Validation Loss: 0.0264
# Epoch 451/500, Train Loss: 0.0293, Validation Loss: 0.0256
# Epoch 452/500, Train Loss: 0.0296, Validation Loss: 0.0264
# Epoch 453/500, Train Loss: 0.0297, Validation Loss: 0.0302
# Epoch 454/500, Train Loss: 0.0292, Validation Loss: 0.0271
# Epoch 455/500, Train Loss: 0.0294, Validation Loss: 0.0266
# Epoch 456/500, Train Loss: 0.0292, Validation Loss: 0.0294
# Epoch 457/500, Train Loss: 0.0291, Validation Loss: 0.0278
# Epoch 458/500, Train Loss: 0.0298, Validation Loss: 0.0281
# Epoch 459/500, Train Loss: 0.0294, Validation Loss: 0.0273
# Epoch 460/500, Train Loss: 0.0293, Validation Loss: 0.0263
# Epoch 461/500, Train Loss: 0.0293, Validation Loss: 0.0259
# Epoch 462/500, Train Loss: 0.0291, Validation Loss: 0.0268
# Epoch 463/500, Train Loss: 0.0291, Validation Loss: 0.0272
# Epoch 464/500, Train Loss: 0.0293, Validation Loss: 0.0266
# Epoch 465/500, Train Loss: 0.0293, Validation Loss: 0.0261
# Epoch 466/500, Train Loss: 0.0296, Validation Loss: 0.0261
# Epoch 467/500, Train Loss: 0.0294, Validation Loss: 0.0262
# Epoch 468/500, Train Loss: 0.0293, Validation Loss: 0.0265
# Epoch 469/500, Train Loss: 0.0293, Validation Loss: 0.0268
# Epoch 470/500, Train Loss: 0.0295, Validation Loss: 0.0256
# Epoch 471/500, Train Loss: 0.0292, Validation Loss: 0.0254
# Epoch 472/500, Train Loss: 0.0292, Validation Loss: 0.0320
# Epoch 473/500, Train Loss: 0.0292, Validation Loss: 0.0258
# Epoch 474/500, Train Loss: 0.0291, Validation Loss: 0.0262
# Epoch 475/500, Train Loss: 0.0293, Validation Loss: 0.0293
# Epoch 476/500, Train Loss: 0.0291, Validation Loss: 0.0308
# Epoch 477/500, Train Loss: 0.0297, Validation Loss: 0.0263
# Epoch 478/500, Train Loss: 0.0293, Validation Loss: 0.0273
# Epoch 479/500, Train Loss: 0.0292, Validation Loss: 0.0263
# Epoch 480/500, Train Loss: 0.0292, Validation Loss: 0.0255
# Epoch 481/500, Train Loss: 0.0294, Validation Loss: 0.0331
# Epoch 482/500, Train Loss: 0.0294, Validation Loss: 0.0259
# Epoch 483/500, Train Loss: 0.0295, Validation Loss: 0.0270
# Epoch 484/500, Train Loss: 0.0294, Validation Loss: 0.0258
# Epoch 485/500, Train Loss: 0.0294, Validation Loss: 0.0281
# Epoch 486/500, Train Loss: 0.0292, Validation Loss: 0.0258
# Epoch 487/500, Train Loss: 0.0292, Validation Loss: 0.0297
# Epoch 488/500, Train Loss: 0.0292, Validation Loss: 0.0278
# Epoch 489/500, Train Loss: 0.0292, Validation Loss: 0.0266
# Epoch 490/500, Train Loss: 0.0298, Validation Loss: 0.0374
# Epoch 491/500, Train Loss: 0.0297, Validation Loss: 0.0314
# Epoch 492/500, Train Loss: 0.0292, Validation Loss: 0.0262
# Epoch 493/500, Train Loss: 0.0293, Validation Loss: 0.0310
# Epoch 494/500, Train Loss: 0.0298, Validation Loss: 0.0264
# Epoch 495/500, Train Loss: 0.0295, Validation Loss: 0.0257
# Epoch 496/500, Train Loss: 0.0292, Validation Loss: 0.0265
# Epoch 497/500, Train Loss: 0.0293, Validation Loss: 0.0259
# Epoch 498/500, Train Loss: 0.0292, Validation Loss: 0.0262
# Epoch 499/500, Train Loss: 0.0290, Validation Loss: 0.0260
# Epoch 500/500, Train Loss: 0.0292, Validation Loss: 0.0263

# %%
# Evaluate the final model on the test data
model.eval()  # Set the model to evaluation mode
test_loss = 0
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        predicted_final_state = model(initial_sample.unsqueeze(1))
        loss = combined_loss(predicted_final_state, final_sample.unsqueeze(1))
        test_loss += loss.item()

print(f'Test Loss: {test_loss/len(test_loader):.4f}')
# Out:
# Test Loss: 0.0264

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Visualize predictions on the test set
def plot_3d_slice(predicted, ground_truth, sample_index=0, slice_index=15):
    predicted_slice = predicted[sample_index, 0, slice_index, :, :].detach().cpu().numpy()  # For predicted tensor with channel dimension
    ground_truth_slice = ground_truth[sample_index, slice_index, :, :].detach().cpu().numpy()  # For ground truth tensor without channel dimension

    # Plotting
    fig, ax = plt.subplots(1, 2, figsize=(12, 6))
    ax[0].imshow(predicted_slice, cmap='hot', interpolation='nearest')
    ax[0].set_title("Predicted")
    ax[0].axis('off')

    ax[1].imshow(ground_truth_slice, cmap='hot', interpolation='nearest')
    ax[1].set_title("Ground Truth")
    ax[1].axis('off')

    plt.show()

# Example usage with a sample index of 0 and a slice index of 15
model.eval()
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        predicted_final_state = model(initial_sample.unsqueeze(1))

        # Visualize the first sample and slice
        plot_3d_slice(predicted_final_state, final_sample, sample_index=0, slice_index=15)
        break  # Just plot one batch for demonstration

# %%
# !pip install pytorch-msssim
# Out:
# Requirement already satisfied: pytorch-msssim in /home/wfarz001/envs/default-pytorch-gpu-2.1.0/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from pytorch-msssim) (2.1.0+cu118)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.12.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (2023.4.0)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->pytorch-msssim) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->pytorch-msssim) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
def rmse(predictions, targets):
    return torch.sqrt(torch.mean((predictions - targets) ** 2))

def mae(predictions, targets):
    return torch.mean(torch.abs(predictions - targets))

from sklearn.metrics import r2_score

def r2_score_pytorch(predictions, targets):
    predictions = predictions.detach().cpu().numpy()  # Convert to numpy
    targets = targets.detach().cpu().numpy()
    return r2_score(targets.flatten(), predictions.flatten())

def psnr(predictions, targets, max_pixel=1.0):
    mse = torch.mean((predictions - targets) ** 2)
    psnr_value = 20 * torch.log10(max_pixel / torch.sqrt(mse))
    return psnr_value

from pytorch_msssim import ssim

def compute_ssim(predictions, targets):
    return ssim(predictions, targets)

def dice_coefficient(predictions, targets, threshold=0.5):
    # Convert to binary masks based on the threshold
    predictions = predictions > threshold
    targets = targets > threshold
    intersection = torch.sum(predictions * targets)
    union = torch.sum(predictions) + torch.sum(targets)
    return (2 * intersection + 1e-6) / (union + 1e-6)

def mape(predictions, targets):
    return torch.mean(torch.abs((predictions - targets) / targets)) * 100

# %%
from sklearn.metrics import r2_score

# Initialize the metrics
rmse_vals = []
mae_vals = []
r2_vals = []
psnr_vals = []
ssim_vals = []
dsc_vals = []
mape_vals = []

model.eval()  # Set the model to evaluation mode
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        
        predicted_final_state = model(initial_sample.unsqueeze(1))  # Add channel dimension (1 for grayscale)

        # Calculate each metric
        rmse_vals.append(rmse(predicted_final_state, final_sample.unsqueeze(1)).item())
        mae_vals.append(mae(predicted_final_state, final_sample.unsqueeze(1)).item())
        r2_vals.append(r2_score_pytorch(predicted_final_state, final_sample.unsqueeze(1)))
        psnr_vals.append(psnr(predicted_final_state, final_sample.unsqueeze(1)).item())
        ssim_vals.append(compute_ssim(predicted_final_state, final_sample.unsqueeze(1)).item())
        dsc_vals.append(dice_coefficient(predicted_final_state, final_sample.unsqueeze(1)).item())
        mape_vals.append(mape(predicted_final_state, final_sample.unsqueeze(1)).item())

# Average the results over the test set
print(f"Average RMSE: {torch.mean(torch.tensor(rmse_vals))}")
print(f"Average MAE: {torch.mean(torch.tensor(mae_vals))}")
print(f"Average R² Score: {torch.mean(torch.tensor(r2_vals))}")
print(f"Average PSNR: {torch.mean(torch.tensor(psnr_vals))}")
print(f"Average SSIM: {torch.mean(torch.tensor(ssim_vals))}")
print(f"Average Dice Similarity Coefficient: {torch.mean(torch.tensor(dsc_vals))}")
print(f"Average MAPE: {torch.mean(torch.tensor(mape_vals))}%")
# Out:
# Average RMSE: 0.03843320906162262
# Average MAE: 0.007660480681806803
# Average R² Score: 0.7748765980488436
# Average PSNR: 28.631433486938477
# Average SSIM: 0.9994739294052124
# Average Dice Similarity Coefficient: 0.542427659034729
# Average MAPE: 1.921990584477786e+23%
