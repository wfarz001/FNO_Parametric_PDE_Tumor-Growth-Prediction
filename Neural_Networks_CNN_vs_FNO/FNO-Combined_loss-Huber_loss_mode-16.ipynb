# %%
#!pip install torchmetrics

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from skimage.metrics import structural_similarity as ssim
import pandas as pd

# %%
from torchmetrics.functional import structural_similarity_index_measure

def ssim_loss(pred, target):
    return 1 - structural_similarity_index_measure(pred, target, data_range=1.0)  # For normalized inputs

# %%
def combined_loss(pred, target, alpha=0.5):
    # Initialize the Huber (Smooth L1) loss
    mse = nn.SmoothL1Loss()
    
    # Compute MSE (Huber) loss
    mse_loss = mse(pred, target)
    
    # Compute SSIM loss
    ssim = ssim_loss(pred, target)
    
    # Combine the losses
    return alpha * mse_loss + (1 - alpha) * ssim

# %%
class TumorDataset(Dataset):
    def __init__(self, initial_dir, final_dir, transform=None):
        self.initial_dir = initial_dir
        self.final_dir = final_dir
        self.transform = transform
        self.initial_files = sorted(os.listdir(initial_dir))  # List of initial state files
        self.final_files = sorted(os.listdir(final_dir))  # List of final state files
        
    def __len__(self):
        return len(self.initial_files)
    
    def __getitem__(self, idx):
        # Load initial state
        initial_file = os.path.join(self.initial_dir, self.initial_files[idx])
        final_file = os.path.join(self.final_dir, self.final_files[idx])
        
        initial_sample = np.load(initial_file)  # Assuming .npy format, shape: (D, H, W)
        final_sample = np.load(final_file)  # Assuming .npy format, shape: (D, H, W)
        
        # Convert to torch tensors
        initial_sample = torch.tensor(initial_sample, dtype=torch.float32)
        final_sample = torch.tensor(final_sample, dtype=torch.float32)
        
        if self.transform:
            initial_sample = self.transform(initial_sample)
            final_sample = self.transform(final_sample)
        
        return initial_sample, final_sample

# %%
import torch

class FNO3D(torch.nn.Module):
    def __init__(self, modes, width):
        super(FNO3D, self).__init__()
        self.modes = modes
        self.width = width
        # Define layers here
        self.fourier_layer1 = torch.nn.Conv3d(1, width, kernel_size=1)
        self.fourier_layer2 = torch.nn.Conv3d(width, width, kernel_size=1)
        self.fourier_layer3 = torch.nn.Conv3d(width, 1, kernel_size=1)

    def forward(self, x):
        # Fourier forward pass
        x = self.fourier_layer1(x)
        x = torch.fft.fftn(x, dim=(2, 3, 4))  # Fourier transform (forward pass)
        
        # Separate the real and imaginary parts
        real_x = torch.real(x)
        imag_x = torch.imag(x)
        
        # Apply convolutional layers on both real and imaginary parts
        real_x = self.fourier_layer2(real_x)
        imag_x = self.fourier_layer2(imag_x)
        
        # Combine real and imaginary parts back into a complex tensor
        x = torch.complex(real_x, imag_x)
        
        # Inverse Fourier transform (we can either take the real part or both)
        x = torch.fft.ifftn(x, dim=(2, 3, 4))  # Inverse Fourier transform
        
        # After inverse FFT, take only the real part if desired (convolution expects real values)
        x = torch.real(x)  # Take real part after inverse FFT
        
        # Apply final convolution
        x = self.fourier_layer3(x)
        return x

# %%
# Paths to the data
initial_samples_folder = '/home/wfarz001/Fall-2024_Project/Tumor_States/Initial/'
final_samples_folder = '/home/wfarz001/Fall-2024_Project/Tumor_States/Final/'

# %%
# Initialize dataset and dataloaders
dataset = TumorDataset(initial_samples_folder, final_samples_folder)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Initialize model, loss function, and optimizer
model = FNO3D(modes=8, width=32).to(device)  # Ensure to place model on GPU if available
optimizer = optim.Adam(model.parameters(), lr=1e-4)
#loss_fn = nn.L1Loss()

# %%
#Train, Validation and Testing ######

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

class TumorDataset(Dataset):
    def __init__(self, initial_dir, final_dir, transform=None):
        self.initial_dir = initial_dir
        self.final_dir = final_dir
        self.transform = transform
        self.initial_files = sorted(os.listdir(initial_dir))  # List of initial state files
        self.final_files = sorted(os.listdir(final_dir))  # List of final state files
        
    def __len__(self):
        return len(self.initial_files)
    
    def __getitem__(self, idx):
        initial_file = os.path.join(self.initial_dir, self.initial_files[idx])
        final_file = os.path.join(self.final_dir, self.final_files[idx])
        
        initial_sample = np.load(initial_file)  # Assuming .npy format
        final_sample = np.load(final_file)  # Assuming .npy format
        
        # Convert to torch tensors
        initial_sample = torch.tensor(initial_sample, dtype=torch.float32)
        final_sample = torch.tensor(final_sample, dtype=torch.float32)
        
        if self.transform:
            initial_sample = self.transform(initial_sample)
            final_sample = self.transform(final_sample)
        
        return initial_sample, final_sample

# Create dataset and split it into train, validation, and test
dataset = TumorDataset(initial_samples_folder, final_samples_folder)
train_data, test_data = train_test_split(dataset, test_size=0.3, random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42)

train_loader = DataLoader(train_data, batch_size=4, shuffle=True)
val_loader = DataLoader(val_data, batch_size=4, shuffle=False)
test_loader = DataLoader(test_data, batch_size=4, shuffle=False)

# %%
import torch.optim as optim
import torch.nn as nn

# Initialize the model, optimizer, and loss function
model = FNO3D(modes=16, width=32).to(device)  # Ensure to place model on GPU if available
optimizer = optim.Adam(model.parameters(), lr=1e-4)
#loss_fn = nn.MSELoss()

# Training loop with validation
num_epochs = 500
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for initial_sample, final_sample in train_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)

        optimizer.zero_grad()
        predicted_final_state = model(initial_sample.unsqueeze(1))  # Add channel dimension (1 for grayscale)
        
        # Compute loss and backpropagate
        loss = combined_loss(predicted_final_state, final_sample.unsqueeze(1))
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # Validation phase after each epoch
    model.eval()  # Set the model to evaluation mode
    val_loss = 0
    with torch.no_grad():
        for initial_sample, final_sample in val_loader:
            initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
            predicted_final_state = model(initial_sample.unsqueeze(1))
            loss = combined_loss(predicted_final_state, final_sample.unsqueeze(1))
            val_loss += loss.item()

    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {total_loss/len(train_loader):.4f}, Validation Loss: {val_loss/len(val_loader):.4f}')
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:605: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv3d(
# /home/wfarz001/envs/default-pytorch-gpu-2.1.0/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:70: FutureWarning: Importing `spectral_angle_mapper` from `torchmetrics.functional` was deprecated and will be removed in 2.0. Import `spectral_angle_mapper` from `torchmetrics.image` instead.
#   _future_warning(
# Epoch 1/500, Train Loss: 0.3892, Validation Loss: 0.0715
# Epoch 2/500, Train Loss: 0.0766, Validation Loss: 0.0672
# Epoch 3/500, Train Loss: 0.0610, Validation Loss: 0.0646
# Epoch 4/500, Train Loss: 0.0600, Validation Loss: 0.0645
# Epoch 5/500, Train Loss: 0.0598, Validation Loss: 0.0645
# Epoch 6/500, Train Loss: 0.0597, Validation Loss: 0.0644
# Epoch 7/500, Train Loss: 0.0597, Validation Loss: 0.0643
# Epoch 8/500, Train Loss: 0.0595, Validation Loss: 0.0642
# Epoch 9/500, Train Loss: 0.0594, Validation Loss: 0.0641
# Epoch 10/500, Train Loss: 0.0593, Validation Loss: 0.0640
# Epoch 11/500, Train Loss: 0.0592, Validation Loss: 0.0639
# Epoch 12/500, Train Loss: 0.0590, Validation Loss: 0.0638
# Epoch 13/500, Train Loss: 0.0589, Validation Loss: 0.0636
# Epoch 14/500, Train Loss: 0.0587, Validation Loss: 0.0635
# Epoch 15/500, Train Loss: 0.0585, Validation Loss: 0.0634
# Epoch 16/500, Train Loss: 0.0583, Validation Loss: 0.0633
# Epoch 17/500, Train Loss: 0.0581, Validation Loss: 0.0630
# Epoch 18/500, Train Loss: 0.0579, Validation Loss: 0.0629
# Epoch 19/500, Train Loss: 0.0577, Validation Loss: 0.0628
# Epoch 20/500, Train Loss: 0.0575, Validation Loss: 0.0625
# Epoch 21/500, Train Loss: 0.0572, Validation Loss: 0.0623
# Epoch 22/500, Train Loss: 0.0570, Validation Loss: 0.0621
# Epoch 23/500, Train Loss: 0.0568, Validation Loss: 0.0619
# Epoch 24/500, Train Loss: 0.0565, Validation Loss: 0.0616
# Epoch 25/500, Train Loss: 0.0562, Validation Loss: 0.0615
# Epoch 26/500, Train Loss: 0.0560, Validation Loss: 0.0614
# Epoch 27/500, Train Loss: 0.0557, Validation Loss: 0.0610
# Epoch 28/500, Train Loss: 0.0554, Validation Loss: 0.0607
# Epoch 29/500, Train Loss: 0.0551, Validation Loss: 0.0605
# Epoch 30/500, Train Loss: 0.0549, Validation Loss: 0.0603
# Epoch 31/500, Train Loss: 0.0546, Validation Loss: 0.0600
# Epoch 32/500, Train Loss: 0.0542, Validation Loss: 0.0598
# Epoch 33/500, Train Loss: 0.0539, Validation Loss: 0.0595
# Epoch 34/500, Train Loss: 0.0536, Validation Loss: 0.0592
# Epoch 35/500, Train Loss: 0.0533, Validation Loss: 0.0590
# Epoch 36/500, Train Loss: 0.0530, Validation Loss: 0.0587
# Epoch 37/500, Train Loss: 0.0527, Validation Loss: 0.0584
# Epoch 38/500, Train Loss: 0.0525, Validation Loss: 0.0583
# Epoch 39/500, Train Loss: 0.0522, Validation Loss: 0.0579
# Epoch 40/500, Train Loss: 0.0520, Validation Loss: 0.0582
# Epoch 41/500, Train Loss: 0.0516, Validation Loss: 0.0575
# Epoch 42/500, Train Loss: 0.0512, Validation Loss: 0.0572
# Epoch 43/500, Train Loss: 0.0509, Validation Loss: 0.0569
# Epoch 44/500, Train Loss: 0.0507, Validation Loss: 0.0568
# Epoch 45/500, Train Loss: 0.0504, Validation Loss: 0.0566
# Epoch 46/500, Train Loss: 0.0501, Validation Loss: 0.0562
# Epoch 47/500, Train Loss: 0.0499, Validation Loss: 0.0560
# Epoch 48/500, Train Loss: 0.0496, Validation Loss: 0.0559
# Epoch 49/500, Train Loss: 0.0494, Validation Loss: 0.0557
# Epoch 50/500, Train Loss: 0.0491, Validation Loss: 0.0561
# Epoch 51/500, Train Loss: 0.0489, Validation Loss: 0.0551
# Epoch 52/500, Train Loss: 0.0487, Validation Loss: 0.0551
# Epoch 53/500, Train Loss: 0.0484, Validation Loss: 0.0549
# Epoch 54/500, Train Loss: 0.0481, Validation Loss: 0.0544
# Epoch 55/500, Train Loss: 0.0479, Validation Loss: 0.0544
# Epoch 56/500, Train Loss: 0.0479, Validation Loss: 0.0540
# Epoch 57/500, Train Loss: 0.0476, Validation Loss: 0.0539
# Epoch 58/500, Train Loss: 0.0474, Validation Loss: 0.0536
# Epoch 59/500, Train Loss: 0.0470, Validation Loss: 0.0536
# Epoch 60/500, Train Loss: 0.0469, Validation Loss: 0.0533
# Epoch 61/500, Train Loss: 0.0471, Validation Loss: 0.0530
# Epoch 62/500, Train Loss: 0.0464, Validation Loss: 0.0531
# Epoch 63/500, Train Loss: 0.0467, Validation Loss: 0.0541
# Epoch 64/500, Train Loss: 0.0463, Validation Loss: 0.0528
# Epoch 65/500, Train Loss: 0.0464, Validation Loss: 0.0538
# Epoch 66/500, Train Loss: 0.0460, Validation Loss: 0.0527
# Epoch 67/500, Train Loss: 0.0460, Validation Loss: 0.0526
# Epoch 68/500, Train Loss: 0.0459, Validation Loss: 0.0522
# Epoch 69/500, Train Loss: 0.0455, Validation Loss: 0.0518
# Epoch 70/500, Train Loss: 0.0453, Validation Loss: 0.0520
# Epoch 71/500, Train Loss: 0.0453, Validation Loss: 0.0518
# Epoch 72/500, Train Loss: 0.0453, Validation Loss: 0.0523
# Epoch 73/500, Train Loss: 0.0449, Validation Loss: 0.0512
# Epoch 74/500, Train Loss: 0.0446, Validation Loss: 0.0512
# Epoch 75/500, Train Loss: 0.0445, Validation Loss: 0.0510
# Epoch 76/500, Train Loss: 0.0444, Validation Loss: 0.0511
# Epoch 77/500, Train Loss: 0.0444, Validation Loss: 0.0512
# Epoch 78/500, Train Loss: 0.0446, Validation Loss: 0.0524
# Epoch 79/500, Train Loss: 0.0444, Validation Loss: 0.0509
# Epoch 80/500, Train Loss: 0.0443, Validation Loss: 0.0503
# Epoch 81/500, Train Loss: 0.0446, Validation Loss: 0.0518
# Epoch 82/500, Train Loss: 0.0441, Validation Loss: 0.0501
# Epoch 83/500, Train Loss: 0.0436, Validation Loss: 0.0500
# Epoch 84/500, Train Loss: 0.0437, Validation Loss: 0.0500
# Epoch 85/500, Train Loss: 0.0437, Validation Loss: 0.0498
# Epoch 86/500, Train Loss: 0.0441, Validation Loss: 0.0497
# Epoch 87/500, Train Loss: 0.0439, Validation Loss: 0.0498
# Epoch 88/500, Train Loss: 0.0432, Validation Loss: 0.0495
# Epoch 89/500, Train Loss: 0.0434, Validation Loss: 0.0494
# Epoch 90/500, Train Loss: 0.0432, Validation Loss: 0.0495
# Epoch 91/500, Train Loss: 0.0430, Validation Loss: 0.0492
# Epoch 92/500, Train Loss: 0.0429, Validation Loss: 0.0494
# Epoch 93/500, Train Loss: 0.0428, Validation Loss: 0.0491
# Epoch 94/500, Train Loss: 0.0430, Validation Loss: 0.0490
# Epoch 95/500, Train Loss: 0.0428, Validation Loss: 0.0494
# Epoch 96/500, Train Loss: 0.0431, Validation Loss: 0.0489
# Epoch 97/500, Train Loss: 0.0426, Validation Loss: 0.0490
# Epoch 98/500, Train Loss: 0.0426, Validation Loss: 0.0501
# Epoch 99/500, Train Loss: 0.0428, Validation Loss: 0.0486
# Epoch 100/500, Train Loss: 0.0425, Validation Loss: 0.0486
# Epoch 101/500, Train Loss: 0.0424, Validation Loss: 0.0486
# Epoch 102/500, Train Loss: 0.0425, Validation Loss: 0.0487
# Epoch 103/500, Train Loss: 0.0428, Validation Loss: 0.0485
# Epoch 104/500, Train Loss: 0.0423, Validation Loss: 0.0486
# Epoch 105/500, Train Loss: 0.0421, Validation Loss: 0.0487
# Epoch 106/500, Train Loss: 0.0422, Validation Loss: 0.0493
# Epoch 107/500, Train Loss: 0.0429, Validation Loss: 0.0492
# Epoch 108/500, Train Loss: 0.0422, Validation Loss: 0.0481
# Epoch 109/500, Train Loss: 0.0425, Validation Loss: 0.0480
# Epoch 110/500, Train Loss: 0.0421, Validation Loss: 0.0481
# Epoch 111/500, Train Loss: 0.0421, Validation Loss: 0.0481
# Epoch 112/500, Train Loss: 0.0420, Validation Loss: 0.0478
# Epoch 113/500, Train Loss: 0.0419, Validation Loss: 0.0479
# Epoch 114/500, Train Loss: 0.0418, Validation Loss: 0.0478
# Epoch 115/500, Train Loss: 0.0419, Validation Loss: 0.0480
# Epoch 116/500, Train Loss: 0.0419, Validation Loss: 0.0487
# Epoch 117/500, Train Loss: 0.0421, Validation Loss: 0.0482
# Epoch 118/500, Train Loss: 0.0421, Validation Loss: 0.0476
# Epoch 119/500, Train Loss: 0.0417, Validation Loss: 0.0475
# Epoch 120/500, Train Loss: 0.0416, Validation Loss: 0.0479
# Epoch 121/500, Train Loss: 0.0419, Validation Loss: 0.0476
# Epoch 122/500, Train Loss: 0.0420, Validation Loss: 0.0477
# Epoch 123/500, Train Loss: 0.0415, Validation Loss: 0.0473
# Epoch 124/500, Train Loss: 0.0419, Validation Loss: 0.0473
# Epoch 125/500, Train Loss: 0.0420, Validation Loss: 0.0483
# Epoch 126/500, Train Loss: 0.0419, Validation Loss: 0.0490
# Epoch 127/500, Train Loss: 0.0421, Validation Loss: 0.0476
# Epoch 128/500, Train Loss: 0.0416, Validation Loss: 0.0475
# Epoch 129/500, Train Loss: 0.0425, Validation Loss: 0.0496
# Epoch 130/500, Train Loss: 0.0418, Validation Loss: 0.0471
# Epoch 131/500, Train Loss: 0.0414, Validation Loss: 0.0474
# Epoch 132/500, Train Loss: 0.0413, Validation Loss: 0.0476
# Epoch 133/500, Train Loss: 0.0416, Validation Loss: 0.0479
# Epoch 134/500, Train Loss: 0.0415, Validation Loss: 0.0471
# Epoch 135/500, Train Loss: 0.0414, Validation Loss: 0.0475
# Epoch 136/500, Train Loss: 0.0414, Validation Loss: 0.0470
# Epoch 137/500, Train Loss: 0.0414, Validation Loss: 0.0468
# Epoch 138/500, Train Loss: 0.0413, Validation Loss: 0.0470
# Epoch 139/500, Train Loss: 0.0417, Validation Loss: 0.0473
# Epoch 140/500, Train Loss: 0.0413, Validation Loss: 0.0472
# Epoch 141/500, Train Loss: 0.0411, Validation Loss: 0.0471
# Epoch 142/500, Train Loss: 0.0412, Validation Loss: 0.0469
# Epoch 143/500, Train Loss: 0.0413, Validation Loss: 0.0473
# Epoch 144/500, Train Loss: 0.0415, Validation Loss: 0.0469
# Epoch 145/500, Train Loss: 0.0413, Validation Loss: 0.0470
# Epoch 146/500, Train Loss: 0.0414, Validation Loss: 0.0474
# Epoch 147/500, Train Loss: 0.0417, Validation Loss: 0.0469
# Epoch 148/500, Train Loss: 0.0413, Validation Loss: 0.0466
# Epoch 149/500, Train Loss: 0.0416, Validation Loss: 0.0475
# Epoch 150/500, Train Loss: 0.0412, Validation Loss: 0.0466
# Epoch 151/500, Train Loss: 0.0412, Validation Loss: 0.0467
# Epoch 152/500, Train Loss: 0.0421, Validation Loss: 0.0480
# Epoch 153/500, Train Loss: 0.0416, Validation Loss: 0.0466
# Epoch 154/500, Train Loss: 0.0415, Validation Loss: 0.0487
# Epoch 155/500, Train Loss: 0.0412, Validation Loss: 0.0464
# Epoch 156/500, Train Loss: 0.0412, Validation Loss: 0.0473
# Epoch 157/500, Train Loss: 0.0411, Validation Loss: 0.0464
# Epoch 158/500, Train Loss: 0.0413, Validation Loss: 0.0467
# Epoch 159/500, Train Loss: 0.0411, Validation Loss: 0.0467
# Epoch 160/500, Train Loss: 0.0410, Validation Loss: 0.0464
# Epoch 161/500, Train Loss: 0.0411, Validation Loss: 0.0467
# Epoch 162/500, Train Loss: 0.0416, Validation Loss: 0.0465
# Epoch 163/500, Train Loss: 0.0413, Validation Loss: 0.0463
# Epoch 164/500, Train Loss: 0.0415, Validation Loss: 0.0469
# Epoch 165/500, Train Loss: 0.0410, Validation Loss: 0.0464
# Epoch 166/500, Train Loss: 0.0411, Validation Loss: 0.0465
# Epoch 167/500, Train Loss: 0.0410, Validation Loss: 0.0463
# Epoch 168/500, Train Loss: 0.0410, Validation Loss: 0.0465
# Epoch 169/500, Train Loss: 0.0411, Validation Loss: 0.0470
# Epoch 170/500, Train Loss: 0.0411, Validation Loss: 0.0467
# Epoch 171/500, Train Loss: 0.0417, Validation Loss: 0.0466
# Epoch 172/500, Train Loss: 0.0410, Validation Loss: 0.0463
# Epoch 173/500, Train Loss: 0.0421, Validation Loss: 0.0477
# Epoch 174/500, Train Loss: 0.0419, Validation Loss: 0.0467
# Epoch 175/500, Train Loss: 0.0414, Validation Loss: 0.0462
# Epoch 176/500, Train Loss: 0.0410, Validation Loss: 0.0481
# Epoch 177/500, Train Loss: 0.0414, Validation Loss: 0.0462
# Epoch 178/500, Train Loss: 0.0411, Validation Loss: 0.0476
# Epoch 179/500, Train Loss: 0.0414, Validation Loss: 0.0462
# Epoch 180/500, Train Loss: 0.0409, Validation Loss: 0.0461
# Epoch 181/500, Train Loss: 0.0412, Validation Loss: 0.0462
# Epoch 182/500, Train Loss: 0.0411, Validation Loss: 0.0466
# Epoch 183/500, Train Loss: 0.0410, Validation Loss: 0.0463
# Epoch 184/500, Train Loss: 0.0414, Validation Loss: 0.0461
# Epoch 185/500, Train Loss: 0.0413, Validation Loss: 0.0471
# Epoch 186/500, Train Loss: 0.0411, Validation Loss: 0.0462
# Epoch 187/500, Train Loss: 0.0409, Validation Loss: 0.0461
# Epoch 188/500, Train Loss: 0.0418, Validation Loss: 0.0468
# Epoch 189/500, Train Loss: 0.0415, Validation Loss: 0.0460
# Epoch 190/500, Train Loss: 0.0416, Validation Loss: 0.0468
# Epoch 191/500, Train Loss: 0.0417, Validation Loss: 0.0482
# Epoch 192/500, Train Loss: 0.0415, Validation Loss: 0.0460
# Epoch 193/500, Train Loss: 0.0409, Validation Loss: 0.0460
# Epoch 194/500, Train Loss: 0.0410, Validation Loss: 0.0461
# Epoch 195/500, Train Loss: 0.0408, Validation Loss: 0.0460
# Epoch 196/500, Train Loss: 0.0409, Validation Loss: 0.0460
# Epoch 197/500, Train Loss: 0.0414, Validation Loss: 0.0475
# Epoch 198/500, Train Loss: 0.0414, Validation Loss: 0.0465
# Epoch 199/500, Train Loss: 0.0417, Validation Loss: 0.0464
# Epoch 200/500, Train Loss: 0.0412, Validation Loss: 0.0463
# Epoch 201/500, Train Loss: 0.0409, Validation Loss: 0.0460
# Epoch 202/500, Train Loss: 0.0413, Validation Loss: 0.0461
# Epoch 203/500, Train Loss: 0.0411, Validation Loss: 0.0461
# Epoch 204/500, Train Loss: 0.0409, Validation Loss: 0.0463
# Epoch 205/500, Train Loss: 0.0409, Validation Loss: 0.0467
# Epoch 206/500, Train Loss: 0.0409, Validation Loss: 0.0464
# Epoch 207/500, Train Loss: 0.0410, Validation Loss: 0.0461
# Epoch 208/500, Train Loss: 0.0410, Validation Loss: 0.0464
# Epoch 209/500, Train Loss: 0.0412, Validation Loss: 0.0472
# Epoch 210/500, Train Loss: 0.0413, Validation Loss: 0.0460
# Epoch 211/500, Train Loss: 0.0410, Validation Loss: 0.0466
# Epoch 212/500, Train Loss: 0.0412, Validation Loss: 0.0463
# Epoch 213/500, Train Loss: 0.0410, Validation Loss: 0.0459
# Epoch 214/500, Train Loss: 0.0410, Validation Loss: 0.0461
# Epoch 215/500, Train Loss: 0.0409, Validation Loss: 0.0459
# Epoch 216/500, Train Loss: 0.0408, Validation Loss: 0.0459
# Epoch 217/500, Train Loss: 0.0411, Validation Loss: 0.0460
# Epoch 218/500, Train Loss: 0.0411, Validation Loss: 0.0459
# Epoch 219/500, Train Loss: 0.0411, Validation Loss: 0.0460
# Epoch 220/500, Train Loss: 0.0409, Validation Loss: 0.0459
# Epoch 221/500, Train Loss: 0.0409, Validation Loss: 0.0459
# Epoch 222/500, Train Loss: 0.0412, Validation Loss: 0.0460
# Epoch 223/500, Train Loss: 0.0410, Validation Loss: 0.0461
# Epoch 224/500, Train Loss: 0.0412, Validation Loss: 0.0467
# Epoch 225/500, Train Loss: 0.0417, Validation Loss: 0.0460
# Epoch 226/500, Train Loss: 0.0412, Validation Loss: 0.0464
# Epoch 227/500, Train Loss: 0.0415, Validation Loss: 0.0462
# Epoch 228/500, Train Loss: 0.0414, Validation Loss: 0.0463
# Epoch 229/500, Train Loss: 0.0409, Validation Loss: 0.0461
# Epoch 230/500, Train Loss: 0.0409, Validation Loss: 0.0461
# Epoch 231/500, Train Loss: 0.0409, Validation Loss: 0.0468
# Epoch 232/500, Train Loss: 0.0410, Validation Loss: 0.0460
# Epoch 233/500, Train Loss: 0.0410, Validation Loss: 0.0458
# Epoch 234/500, Train Loss: 0.0409, Validation Loss: 0.0462
# Epoch 235/500, Train Loss: 0.0410, Validation Loss: 0.0460
# Epoch 236/500, Train Loss: 0.0413, Validation Loss: 0.0469
# Epoch 237/500, Train Loss: 0.0412, Validation Loss: 0.0467
# Epoch 238/500, Train Loss: 0.0419, Validation Loss: 0.0473
# Epoch 239/500, Train Loss: 0.0411, Validation Loss: 0.0465
# Epoch 240/500, Train Loss: 0.0410, Validation Loss: 0.0461
# Epoch 241/500, Train Loss: 0.0410, Validation Loss: 0.0458
# Epoch 242/500, Train Loss: 0.0410, Validation Loss: 0.0460
# Epoch 243/500, Train Loss: 0.0410, Validation Loss: 0.0458
# Epoch 244/500, Train Loss: 0.0409, Validation Loss: 0.0465
# Epoch 245/500, Train Loss: 0.0413, Validation Loss: 0.0459
# Epoch 246/500, Train Loss: 0.0413, Validation Loss: 0.0458
# Epoch 247/500, Train Loss: 0.0414, Validation Loss: 0.0458
# Epoch 248/500, Train Loss: 0.0410, Validation Loss: 0.0459
# Epoch 249/500, Train Loss: 0.0410, Validation Loss: 0.0472
# Epoch 250/500, Train Loss: 0.0413, Validation Loss: 0.0465
# Epoch 251/500, Train Loss: 0.0411, Validation Loss: 0.0458
# Epoch 252/500, Train Loss: 0.0409, Validation Loss: 0.0461
# Epoch 253/500, Train Loss: 0.0411, Validation Loss: 0.0458
# Epoch 254/500, Train Loss: 0.0408, Validation Loss: 0.0458
# Epoch 255/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 256/500, Train Loss: 0.0409, Validation Loss: 0.0460
# Epoch 257/500, Train Loss: 0.0415, Validation Loss: 0.0460
# Epoch 258/500, Train Loss: 0.0414, Validation Loss: 0.0462
# Epoch 259/500, Train Loss: 0.0411, Validation Loss: 0.0458
# Epoch 260/500, Train Loss: 0.0414, Validation Loss: 0.0463
# Epoch 261/500, Train Loss: 0.0414, Validation Loss: 0.0466
# Epoch 262/500, Train Loss: 0.0410, Validation Loss: 0.0458
# Epoch 263/500, Train Loss: 0.0408, Validation Loss: 0.0458
# Epoch 264/500, Train Loss: 0.0409, Validation Loss: 0.0458
# Epoch 265/500, Train Loss: 0.0409, Validation Loss: 0.0460
# Epoch 266/500, Train Loss: 0.0409, Validation Loss: 0.0461
# Epoch 267/500, Train Loss: 0.0411, Validation Loss: 0.0460
# Epoch 268/500, Train Loss: 0.0409, Validation Loss: 0.0460
# Epoch 269/500, Train Loss: 0.0410, Validation Loss: 0.0460
# Epoch 270/500, Train Loss: 0.0415, Validation Loss: 0.0463
# Epoch 271/500, Train Loss: 0.0411, Validation Loss: 0.0457
# Epoch 272/500, Train Loss: 0.0409, Validation Loss: 0.0465
# Epoch 273/500, Train Loss: 0.0412, Validation Loss: 0.0471
# Epoch 274/500, Train Loss: 0.0413, Validation Loss: 0.0457
# Epoch 275/500, Train Loss: 0.0409, Validation Loss: 0.0459
# Epoch 276/500, Train Loss: 0.0411, Validation Loss: 0.0457
# Epoch 277/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 278/500, Train Loss: 0.0411, Validation Loss: 0.0478
# Epoch 279/500, Train Loss: 0.0414, Validation Loss: 0.0457
# Epoch 280/500, Train Loss: 0.0410, Validation Loss: 0.0470
# Epoch 281/500, Train Loss: 0.0417, Validation Loss: 0.0460
# Epoch 282/500, Train Loss: 0.0411, Validation Loss: 0.0478
# Epoch 283/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 284/500, Train Loss: 0.0410, Validation Loss: 0.0458
# Epoch 285/500, Train Loss: 0.0409, Validation Loss: 0.0459
# Epoch 286/500, Train Loss: 0.0408, Validation Loss: 0.0458
# Epoch 287/500, Train Loss: 0.0408, Validation Loss: 0.0460
# Epoch 288/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 289/500, Train Loss: 0.0413, Validation Loss: 0.0460
# Epoch 290/500, Train Loss: 0.0416, Validation Loss: 0.0461
# Epoch 291/500, Train Loss: 0.0413, Validation Loss: 0.0470
# Epoch 292/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 293/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 294/500, Train Loss: 0.0408, Validation Loss: 0.0458
# Epoch 295/500, Train Loss: 0.0412, Validation Loss: 0.0458
# Epoch 296/500, Train Loss: 0.0413, Validation Loss: 0.0458
# Epoch 297/500, Train Loss: 0.0412, Validation Loss: 0.0459
# Epoch 298/500, Train Loss: 0.0410, Validation Loss: 0.0469
# Epoch 299/500, Train Loss: 0.0410, Validation Loss: 0.0460
# Epoch 300/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 301/500, Train Loss: 0.0412, Validation Loss: 0.0457
# Epoch 302/500, Train Loss: 0.0411, Validation Loss: 0.0464
# Epoch 303/500, Train Loss: 0.0412, Validation Loss: 0.0458
# Epoch 304/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 305/500, Train Loss: 0.0415, Validation Loss: 0.0463
# Epoch 306/500, Train Loss: 0.0410, Validation Loss: 0.0457
# Epoch 307/500, Train Loss: 0.0413, Validation Loss: 0.0472
# Epoch 308/500, Train Loss: 0.0418, Validation Loss: 0.0458
# Epoch 309/500, Train Loss: 0.0411, Validation Loss: 0.0457
# Epoch 310/500, Train Loss: 0.0410, Validation Loss: 0.0457
# Epoch 311/500, Train Loss: 0.0411, Validation Loss: 0.0480
# Epoch 312/500, Train Loss: 0.0414, Validation Loss: 0.0458
# Epoch 313/500, Train Loss: 0.0412, Validation Loss: 0.0457
# Epoch 314/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 315/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 316/500, Train Loss: 0.0410, Validation Loss: 0.0461
# Epoch 317/500, Train Loss: 0.0410, Validation Loss: 0.0481
# Epoch 318/500, Train Loss: 0.0412, Validation Loss: 0.0458
# Epoch 319/500, Train Loss: 0.0411, Validation Loss: 0.0457
# Epoch 320/500, Train Loss: 0.0409, Validation Loss: 0.0458
# Epoch 321/500, Train Loss: 0.0408, Validation Loss: 0.0463
# Epoch 322/500, Train Loss: 0.0410, Validation Loss: 0.0457
# Epoch 323/500, Train Loss: 0.0413, Validation Loss: 0.0457
# Epoch 324/500, Train Loss: 0.0410, Validation Loss: 0.0458
# Epoch 325/500, Train Loss: 0.0410, Validation Loss: 0.0458
# Epoch 326/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 327/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 328/500, Train Loss: 0.0416, Validation Loss: 0.0457
# Epoch 329/500, Train Loss: 0.0410, Validation Loss: 0.0466
# Epoch 330/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 331/500, Train Loss: 0.0410, Validation Loss: 0.0460
# Epoch 332/500, Train Loss: 0.0408, Validation Loss: 0.0458
# Epoch 333/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 334/500, Train Loss: 0.0409, Validation Loss: 0.0462
# Epoch 335/500, Train Loss: 0.0418, Validation Loss: 0.0469
# Epoch 336/500, Train Loss: 0.0418, Validation Loss: 0.0462
# Epoch 337/500, Train Loss: 0.0414, Validation Loss: 0.0473
# Epoch 338/500, Train Loss: 0.0408, Validation Loss: 0.0458
# Epoch 339/500, Train Loss: 0.0410, Validation Loss: 0.0460
# Epoch 340/500, Train Loss: 0.0416, Validation Loss: 0.0468
# Epoch 341/500, Train Loss: 0.0424, Validation Loss: 0.0458
# Epoch 342/500, Train Loss: 0.0409, Validation Loss: 0.0458
# Epoch 343/500, Train Loss: 0.0410, Validation Loss: 0.0457
# Epoch 344/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 345/500, Train Loss: 0.0413, Validation Loss: 0.0465
# Epoch 346/500, Train Loss: 0.0420, Validation Loss: 0.0458
# Epoch 347/500, Train Loss: 0.0415, Validation Loss: 0.0463
# Epoch 348/500, Train Loss: 0.0411, Validation Loss: 0.0457
# Epoch 349/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 350/500, Train Loss: 0.0408, Validation Loss: 0.0458
# Epoch 351/500, Train Loss: 0.0411, Validation Loss: 0.0462
# Epoch 352/500, Train Loss: 0.0410, Validation Loss: 0.0458
# Epoch 353/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 354/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 355/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 356/500, Train Loss: 0.0408, Validation Loss: 0.0460
# Epoch 357/500, Train Loss: 0.0409, Validation Loss: 0.0458
# Epoch 358/500, Train Loss: 0.0411, Validation Loss: 0.0457
# Epoch 359/500, Train Loss: 0.0410, Validation Loss: 0.0462
# Epoch 360/500, Train Loss: 0.0411, Validation Loss: 0.0466
# Epoch 361/500, Train Loss: 0.0409, Validation Loss: 0.0458
# Epoch 362/500, Train Loss: 0.0413, Validation Loss: 0.0458
# Epoch 363/500, Train Loss: 0.0419, Validation Loss: 0.0464
# Epoch 364/500, Train Loss: 0.0418, Validation Loss: 0.0457
# Epoch 365/500, Train Loss: 0.0416, Validation Loss: 0.0483
# Epoch 366/500, Train Loss: 0.0413, Validation Loss: 0.0462
# Epoch 367/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 368/500, Train Loss: 0.0410, Validation Loss: 0.0458
# Epoch 369/500, Train Loss: 0.0408, Validation Loss: 0.0458
# Epoch 370/500, Train Loss: 0.0409, Validation Loss: 0.0458
# Epoch 371/500, Train Loss: 0.0409, Validation Loss: 0.0459
# Epoch 372/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 373/500, Train Loss: 0.0413, Validation Loss: 0.0457
# Epoch 374/500, Train Loss: 0.0408, Validation Loss: 0.0458
# Epoch 375/500, Train Loss: 0.0410, Validation Loss: 0.0462
# Epoch 376/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 377/500, Train Loss: 0.0412, Validation Loss: 0.0474
# Epoch 378/500, Train Loss: 0.0412, Validation Loss: 0.0460
# Epoch 379/500, Train Loss: 0.0413, Validation Loss: 0.0464
# Epoch 380/500, Train Loss: 0.0411, Validation Loss: 0.0457
# Epoch 381/500, Train Loss: 0.0417, Validation Loss: 0.0465
# Epoch 382/500, Train Loss: 0.0409, Validation Loss: 0.0461
# Epoch 383/500, Train Loss: 0.0417, Validation Loss: 0.0461
# Epoch 384/500, Train Loss: 0.0409, Validation Loss: 0.0459
# Epoch 385/500, Train Loss: 0.0412, Validation Loss: 0.0465
# Epoch 386/500, Train Loss: 0.0412, Validation Loss: 0.0467
# Epoch 387/500, Train Loss: 0.0410, Validation Loss: 0.0457
# Epoch 388/500, Train Loss: 0.0411, Validation Loss: 0.0461
# Epoch 389/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 390/500, Train Loss: 0.0410, Validation Loss: 0.0471
# Epoch 391/500, Train Loss: 0.0422, Validation Loss: 0.0458
# Epoch 392/500, Train Loss: 0.0414, Validation Loss: 0.0458
# Epoch 393/500, Train Loss: 0.0418, Validation Loss: 0.0459
# Epoch 394/500, Train Loss: 0.0410, Validation Loss: 0.0472
# Epoch 395/500, Train Loss: 0.0411, Validation Loss: 0.0457
# Epoch 396/500, Train Loss: 0.0409, Validation Loss: 0.0466
# Epoch 397/500, Train Loss: 0.0411, Validation Loss: 0.0457
# Epoch 398/500, Train Loss: 0.0409, Validation Loss: 0.0460
# Epoch 399/500, Train Loss: 0.0412, Validation Loss: 0.0462
# Epoch 400/500, Train Loss: 0.0417, Validation Loss: 0.0470
# Epoch 401/500, Train Loss: 0.0423, Validation Loss: 0.0460
# Epoch 402/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 403/500, Train Loss: 0.0411, Validation Loss: 0.0459
# Epoch 404/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 405/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 406/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 407/500, Train Loss: 0.0410, Validation Loss: 0.0460
# Epoch 408/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 409/500, Train Loss: 0.0409, Validation Loss: 0.0461
# Epoch 410/500, Train Loss: 0.0409, Validation Loss: 0.0458
# Epoch 411/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 412/500, Train Loss: 0.0408, Validation Loss: 0.0462
# Epoch 413/500, Train Loss: 0.0421, Validation Loss: 0.0494
# Epoch 414/500, Train Loss: 0.0417, Validation Loss: 0.0461
# Epoch 415/500, Train Loss: 0.0409, Validation Loss: 0.0462
# Epoch 416/500, Train Loss: 0.0413, Validation Loss: 0.0458
# Epoch 417/500, Train Loss: 0.0410, Validation Loss: 0.0461
# Epoch 418/500, Train Loss: 0.0412, Validation Loss: 0.0457
# Epoch 419/500, Train Loss: 0.0412, Validation Loss: 0.0460
# Epoch 420/500, Train Loss: 0.0413, Validation Loss: 0.0457
# Epoch 421/500, Train Loss: 0.0413, Validation Loss: 0.0464
# Epoch 422/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 423/500, Train Loss: 0.0412, Validation Loss: 0.0457
# Epoch 424/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 425/500, Train Loss: 0.0408, Validation Loss: 0.0458
# Epoch 426/500, Train Loss: 0.0410, Validation Loss: 0.0457
# Epoch 427/500, Train Loss: 0.0416, Validation Loss: 0.0465
# Epoch 428/500, Train Loss: 0.0414, Validation Loss: 0.0471
# Epoch 429/500, Train Loss: 0.0413, Validation Loss: 0.0465
# Epoch 430/500, Train Loss: 0.0411, Validation Loss: 0.0461
# Epoch 431/500, Train Loss: 0.0418, Validation Loss: 0.0469
# Epoch 432/500, Train Loss: 0.0422, Validation Loss: 0.0459
# Epoch 433/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 434/500, Train Loss: 0.0408, Validation Loss: 0.0460
# Epoch 435/500, Train Loss: 0.0410, Validation Loss: 0.0463
# Epoch 436/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 437/500, Train Loss: 0.0408, Validation Loss: 0.0459
# Epoch 438/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 439/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 440/500, Train Loss: 0.0410, Validation Loss: 0.0462
# Epoch 441/500, Train Loss: 0.0416, Validation Loss: 0.0458
# Epoch 442/500, Train Loss: 0.0416, Validation Loss: 0.0476
# Epoch 443/500, Train Loss: 0.0413, Validation Loss: 0.0460
# Epoch 444/500, Train Loss: 0.0409, Validation Loss: 0.0465
# Epoch 445/500, Train Loss: 0.0412, Validation Loss: 0.0460
# Epoch 446/500, Train Loss: 0.0408, Validation Loss: 0.0462
# Epoch 447/500, Train Loss: 0.0409, Validation Loss: 0.0464
# Epoch 448/500, Train Loss: 0.0409, Validation Loss: 0.0459
# Epoch 449/500, Train Loss: 0.0409, Validation Loss: 0.0459
# Epoch 450/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 451/500, Train Loss: 0.0412, Validation Loss: 0.0459
# Epoch 452/500, Train Loss: 0.0413, Validation Loss: 0.0459
# Epoch 453/500, Train Loss: 0.0410, Validation Loss: 0.0457
# Epoch 454/500, Train Loss: 0.0412, Validation Loss: 0.0460
# Epoch 455/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 456/500, Train Loss: 0.0410, Validation Loss: 0.0460
# Epoch 457/500, Train Loss: 0.0409, Validation Loss: 0.0464
# Epoch 458/500, Train Loss: 0.0412, Validation Loss: 0.0457
# Epoch 459/500, Train Loss: 0.0409, Validation Loss: 0.0458
# Epoch 460/500, Train Loss: 0.0410, Validation Loss: 0.0464
# Epoch 461/500, Train Loss: 0.0411, Validation Loss: 0.0459
# Epoch 462/500, Train Loss: 0.0409, Validation Loss: 0.0459
# Epoch 463/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 464/500, Train Loss: 0.0413, Validation Loss: 0.0464
# Epoch 465/500, Train Loss: 0.0412, Validation Loss: 0.0457
# Epoch 466/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 467/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 468/500, Train Loss: 0.0415, Validation Loss: 0.0471
# Epoch 469/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 470/500, Train Loss: 0.0413, Validation Loss: 0.0463
# Epoch 471/500, Train Loss: 0.0408, Validation Loss: 0.0459
# Epoch 472/500, Train Loss: 0.0412, Validation Loss: 0.0464
# Epoch 473/500, Train Loss: 0.0408, Validation Loss: 0.0460
# Epoch 474/500, Train Loss: 0.0409, Validation Loss: 0.0470
# Epoch 475/500, Train Loss: 0.0419, Validation Loss: 0.0462
# Epoch 476/500, Train Loss: 0.0410, Validation Loss: 0.0458
# Epoch 477/500, Train Loss: 0.0413, Validation Loss: 0.0457
# Epoch 478/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 479/500, Train Loss: 0.0410, Validation Loss: 0.0457
# Epoch 480/500, Train Loss: 0.0408, Validation Loss: 0.0474
# Epoch 481/500, Train Loss: 0.0418, Validation Loss: 0.0460
# Epoch 482/500, Train Loss: 0.0409, Validation Loss: 0.0461
# Epoch 483/500, Train Loss: 0.0410, Validation Loss: 0.0457
# Epoch 484/500, Train Loss: 0.0411, Validation Loss: 0.0463
# Epoch 485/500, Train Loss: 0.0409, Validation Loss: 0.0458
# Epoch 486/500, Train Loss: 0.0408, Validation Loss: 0.0457
# Epoch 487/500, Train Loss: 0.0411, Validation Loss: 0.0458
# Epoch 488/500, Train Loss: 0.0409, Validation Loss: 0.0458
# Epoch 489/500, Train Loss: 0.0409, Validation Loss: 0.0457
# Epoch 490/500, Train Loss: 0.0412, Validation Loss: 0.0465
# Epoch 491/500, Train Loss: 0.0409, Validation Loss: 0.0463
# Epoch 492/500, Train Loss: 0.0412, Validation Loss: 0.0458
# Epoch 493/500, Train Loss: 0.0410, Validation Loss: 0.0457
# Epoch 494/500, Train Loss: 0.0412, Validation Loss: 0.0460
# Epoch 495/500, Train Loss: 0.0410, Validation Loss: 0.0476
# Epoch 496/500, Train Loss: 0.0411, Validation Loss: 0.0461
# Epoch 497/500, Train Loss: 0.0411, Validation Loss: 0.0461
# Epoch 498/500, Train Loss: 0.0410, Validation Loss: 0.0462
# Epoch 499/500, Train Loss: 0.0412, Validation Loss: 0.0457
# Epoch 500/500, Train Loss: 0.0418, Validation Loss: 0.0458

# %%
# Evaluate the final model on the test data
model.eval()  # Set the model to evaluation mode
test_loss = 0
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        predicted_final_state = model(initial_sample.unsqueeze(1))
        loss = combined_loss(predicted_final_state, final_sample.unsqueeze(1))
        test_loss += loss.item()

print(f'Test Loss: {test_loss/len(test_loader):.4f}')
# Out:
# Test Loss: 0.0428

# %%
# Visualize predictions on the test set
# %matplotlib inline
def plot_3d_slice(predicted, ground_truth, sample_index=0, slice_index=15):
    predicted_slice = predicted[sample_index, 0, slice_index, :, :].detach().cpu().numpy()  # For predicted tensor with channel dimension
    ground_truth_slice = ground_truth[sample_index, slice_index, :, :].detach().cpu().numpy()  # For ground truth tensor without channel dimension

    # Plotting
    fig, ax = plt.subplots(1, 2, figsize=(12, 6))
    ax[0].imshow(predicted_slice, cmap='hot', interpolation='nearest')
    ax[0].set_title("Predicted")
    ax[0].axis('off')

    ax[1].imshow(ground_truth_slice, cmap='hot', interpolation='nearest')
    ax[1].set_title("Ground Truth")
    ax[1].axis('off')

    plt.show()

# Example usage with a sample index of 0 and a slice index of 15
model.eval()
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        predicted_final_state = model(initial_sample.unsqueeze(1))

        # Visualize the first sample and slice
        plot_3d_slice(predicted_final_state, final_sample, sample_index=0, slice_index=15)
        break  # Just plot one batch for demonstration

# %%
# !pip install pytorch-msssim
# Out:
# Requirement already satisfied: pytorch-msssim in /home/wfarz001/envs/default-pytorch-gpu-2.1.0/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from pytorch-msssim) (2.1.0+cu118)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.12.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (2023.4.0)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.10/site-packages (from torch->pytorch-msssim) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->pytorch-msssim) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->pytorch-msssim) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
def rmse(predictions, targets):
    return torch.sqrt(torch.mean((predictions - targets) ** 2))

def mae(predictions, targets):
    return torch.mean(torch.abs(predictions - targets))

from sklearn.metrics import r2_score

def r2_score_pytorch(predictions, targets):
    predictions = predictions.detach().cpu().numpy()  # Convert to numpy
    targets = targets.detach().cpu().numpy()
    return r2_score(targets.flatten(), predictions.flatten())

def psnr(predictions, targets, max_pixel=1.0):
    mse = torch.mean((predictions - targets) ** 2)
    psnr_value = 20 * torch.log10(max_pixel / torch.sqrt(mse))
    return psnr_value

from pytorch_msssim import ssim

def compute_ssim(predictions, targets):
    return ssim(predictions, targets)

def dice_coefficient(predictions, targets, threshold=0.5):
    # Convert to binary masks based on the threshold
    predictions = predictions > threshold
    targets = targets > threshold
    intersection = torch.sum(predictions * targets)
    union = torch.sum(predictions) + torch.sum(targets)
    return (2 * intersection + 1e-6) / (union + 1e-6)

def mape(predictions, targets):
    return torch.mean(torch.abs((predictions - targets) / targets)) * 100

# %%
from sklearn.metrics import r2_score

# Initialize the metrics
rmse_vals = []
mae_vals = []
r2_vals = []
psnr_vals = []
ssim_vals = []
dsc_vals = []
mape_vals = []

model.eval()  # Set the model to evaluation mode
with torch.no_grad():
    for initial_sample, final_sample in test_loader:
        initial_sample, final_sample = initial_sample.to(device), final_sample.to(device)
        
        predicted_final_state = model(initial_sample.unsqueeze(1))  # Add channel dimension (1 for grayscale)

        # Calculate each metric
        rmse_vals.append(rmse(predicted_final_state, final_sample.unsqueeze(1)).item())
        mae_vals.append(mae(predicted_final_state, final_sample.unsqueeze(1)).item())
        r2_vals.append(r2_score_pytorch(predicted_final_state, final_sample.unsqueeze(1)))
        psnr_vals.append(psnr(predicted_final_state, final_sample.unsqueeze(1)).item())
        ssim_vals.append(compute_ssim(predicted_final_state, final_sample.unsqueeze(1)).item())
        dsc_vals.append(dice_coefficient(predicted_final_state, final_sample.unsqueeze(1)).item())
        mape_vals.append(mape(predicted_final_state, final_sample.unsqueeze(1)).item())

# Average the results over the test set
print(f"Average RMSE: {torch.mean(torch.tensor(rmse_vals))}")
print(f"Average MAE: {torch.mean(torch.tensor(mae_vals))}")
print(f"Average R² Score: {torch.mean(torch.tensor(r2_vals))}")
print(f"Average PSNR: {torch.mean(torch.tensor(psnr_vals))}")
print(f"Average SSIM: {torch.mean(torch.tensor(ssim_vals))}")
print(f"Average Dice Similarity Coefficient: {torch.mean(torch.tensor(dsc_vals))}")
print(f"Average MAPE: {torch.mean(torch.tensor(mape_vals))}%")
# Out:
# Average RMSE: 0.064036063849926
# Average MAE: 0.010751675814390182
# Average R² Score: 0.36097613761122627
# Average PSNR: 23.955644607543945
# Average SSIM: 0.9990871548652649
# Average Dice Similarity Coefficient: 0.5271769762039185
# Average MAPE: 9.700683341201861e+22%
